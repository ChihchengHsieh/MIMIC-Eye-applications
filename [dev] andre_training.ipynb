# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 4,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 20,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}
# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_efficientnet_b5",
        **lesion_detection_best_args,
        **efficientnet_b5_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    # ModelSetup(
    #     name="lesion_dsetection_baseline_efficientnet_b5",
    #     **lesion_detection_best_args,
    #     **efficientnet_b5_args,
    #     **small_model_args,
    #     **common_args,
    #     **without_fix_args,
    # ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        val_loss = train_info.val_losses[-1]["loss"]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_loss)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resized
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [1] Done | It has took [12.52] min, Avg time: [751.00] sec/epoch | Estimate time for [50] epochs: [625.83] min | Epoch took [751] sec | Patience [0] |====================
# Evaluation:  [  0/114]  eta: 0:01:51  loss: 0.0962 (0.0962)  lesion-detection_performer-object_detection_loss_classifier: 0.0324 (0.0324)  lesion-detection_performer-object_detection_loss_box_reg: 0.0210 (0.0210)  lesion-detection_performer-object_detection_loss_objectness: 0.0369 (0.0369)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0059 (0.0059)  model_time: 1679098624.0000 (1679098587.0837)  evaluator_time: 0.0000 (0.0000)  time: 0.9803  data: 0.8868  max mem: 13299
# Evaluation:  [100/114]  eta: 0:00:14  loss: 0.1386 (0.1594)  lesion-detection_performer-object_detection_loss_classifier: 0.0590 (0.0683)  lesion-detection_performer-object_detection_loss_box_reg: 0.0413 (0.0440)  lesion-detection_performer-object_detection_loss_objectness: 0.0303 (0.0401)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0050 (0.0070)  model_time: 1679098624.0000 (1679098638.9640)  evaluator_time: 0.0000 (0.0000)  time: 1.0542  data: 0.9414  max mem: 13299
# Evaluation:  [113/114]  eta: 0:00:01  loss: 0.1558 (0.1602)  lesion-detection_performer-object_detection_loss_classifier: 0.0673 (0.0685)  lesion-detection_performer-object_detection_loss_box_reg: 0.0404 (0.0437)  lesion-detection_performer-object_detection_loss_objectness: 0.0340 (0.0409)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0058 (0.0070)  model_time: 1679098752.0000 (1679098645.7425)  evaluator_time: 0.0000 (0.0000)  time: 1.0403  data: 0.9257  max mem: 13299
# Evaluation: Total time: 0:01:58 (1.0380 s / it)
# Averaged stats: loss: 0.1558 (0.1602)  lesion-detection_performer-object_detection_loss_classifier: 0.0673 (0.0685)  lesion-detection_performer-object_detection_loss_box_reg: 0.0404 (0.0437)  lesion-detection_performer-object_detection_loss_objectness: 0.0340 (0.0409)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0058 (0.0070)  model_time: 1679098752.0000 (1679098645.7425)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.020
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.033
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.128
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.128
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.128
# ====================Training model: [lesion_dsetection_with_fixation_efficientnet_b5]====================
# ========================================For Training [lesion_dsetection_with_fixation_efficientnet_b5]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_efficientnet_b5', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b5', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=4, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==============================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_0194_test_lesion-detection_ap_0_0196_epoch1_03-18-2023 10-18-24_lesion_dsetection_with_fixation_efficientnet_b5]
# The final model has been saved to: [val_lesion-detection_ap_0_0194_test_lesion-detection_ap_0_0196_epoch1_03-18-2023 10-18-24_lesion_dsetection_with_fixation_efficientnet_b5]
#
# ==============================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4275
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4622
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.3624
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.2542
# backbone weights fix status: False
# backbone weights fix status: False
# Epoch: [2]  [  0/531]  eta: 0:09:24  lr: 0.010000  loss: 0.1967 (0.1967)  lesion-detection_performer-object_detection_loss_classifier: 0.0896 (0.0896)  lesion-detection_performer-object_detection_loss_box_reg: 0.0803 (0.0803)  lesion-detection_performer-object_detection_loss_objectness: 0.0227 (0.0227)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0041 (0.0041)  time: 1.0639  data: 0.7093  max mem: 13299
# Epoch: [2]  [ 10/531]  eta: 0:07:41  lr: 0.010000  loss: 0.1894 (0.1712)  lesion-detection_performer-object_detection_loss_classifier: 0.0842 (0.0771)  lesion-detection_performer-object_detection_loss_box_reg: 0.0750 (0.0596)  lesion-detection_performer-object_detection_loss_objectness: 0.0227 (0.0291)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0053)  time: 0.8864  data: 0.6730  max mem: 13299
# Epoch: [2]  [ 20/531]  eta: 0:07:17  lr: 0.010000  loss: 0.1845 (0.1770)  lesion-detection_performer-object_detection_loss_classifier: 0.0730 (0.0809)  lesion-detection_performer-object_detection_loss_box_reg: 0.0574 (0.0630)  lesion-detection_performer-object_detection_loss_objectness: 0.0281 (0.0284)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0048)  time: 0.8466  data: 0.6480  max mem: 13299
# Epoch: [2]  [ 30/531]  eta: 0:07:11  lr: 0.010000  loss: 0.1534 (0.1912)  lesion-detection_performer-object_detection_loss_classifier: 0.0705 (0.0881)  lesion-detection_performer-object_detection_loss_box_reg: 0.0517 (0.0683)  lesion-detection_performer-object_detection_loss_objectness: 0.0286 (0.0301)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0046)  time: 0.8484  data: 0.6427  max mem: 13299
# Epoch: [2]  [ 40/531]  eta: 0:07:00  lr: 0.010000  loss: 0.1851 (0.1871)  lesion-detection_performer-object_detection_loss_classifier: 0.0860 (0.0853)  lesion-detection_performer-object_detection_loss_box_reg: 0.0676 (0.0662)  lesion-detection_performer-object_detection_loss_objectness: 0.0286 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0050)  time: 0.8538  data: 0.6435  max mem: 13299
# Epoch: [2]  [ 50/531]  eta: 0:06:48  lr: 0.010000  loss: 0.1851 (0.1888)  lesion-detection_performer-object_detection_loss_classifier: 0.0859 (0.0859)  lesion-detection_performer-object_detection_loss_box_reg: 0.0686 (0.0667)  lesion-detection_performer-object_detection_loss_objectness: 0.0300 (0.0310)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0055 (0.0052)  time: 0.8283  data: 0.6236  max mem: 13299
# Epoch: [2]  [ 60/531]  eta: 0:06:39  lr: 0.010000  loss: 0.2220 (0.1985)  lesion-detection_performer-object_detection_loss_classifier: 0.1012 (0.0894)  lesion-detection_performer-object_detection_loss_box_reg: 0.0839 (0.0722)  lesion-detection_performer-object_detection_loss_objectness: 0.0306 (0.0316)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0046 (0.0053)  time: 0.8319  data: 0.6268  max mem: 13299
# Epoch: [2]  [ 70/531]  eta: 0:06:31  lr: 0.010000  loss: 0.1799 (0.1903)  lesion-detection_performer-object_detection_loss_classifier: 0.0749 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0687 (0.0686)  lesion-detection_performer-object_detection_loss_objectness: 0.0312 (0.0311)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0032 (0.0051)  time: 0.8471  data: 0.6414  max mem: 13299
# Epoch: [2]  [ 80/531]  eta: 0:06:20  lr: 0.010000  loss: 0.1685 (0.1871)  lesion-detection_performer-object_detection_loss_classifier: 0.0711 (0.0844)  lesion-detection_performer-object_detection_loss_box_reg: 0.0624 (0.0674)  lesion-detection_performer-object_detection_loss_objectness: 0.0254 (0.0304)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0032 (0.0049)  time: 0.8339  data: 0.6323  max mem: 13299
# Epoch: [2]  [ 90/531]  eta: 0:06:11  lr: 0.010000  loss: 0.1773 (0.1890)  lesion-detection_performer-object_detection_loss_classifier: 0.0794 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0676 (0.0681)  lesion-detection_performer-object_detection_loss_objectness: 0.0255 (0.0304)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0049)  time: 0.8214  data: 0.6207  max mem: 13299
# Epoch: [2]  [100/531]  eta: 0:06:03  lr: 0.010000  loss: 0.1773 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0772 (0.0848)  lesion-detection_performer-object_detection_loss_box_reg: 0.0664 (0.0674)  lesion-detection_performer-object_detection_loss_objectness: 0.0264 (0.0303)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0048)  time: 0.8364  data: 0.6349  max mem: 13299
# Epoch: [2]  [110/531]  eta: 0:05:54  lr: 0.010000  loss: 0.1449 (0.1845)  lesion-detection_performer-object_detection_loss_classifier: 0.0671 (0.0837)  lesion-detection_performer-object_detection_loss_box_reg: 0.0471 (0.0660)  lesion-detection_performer-object_detection_loss_objectness: 0.0233 (0.0300)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.8388  data: 0.6382  max mem: 13299
# Epoch: [2]  [120/531]  eta: 0:05:46  lr: 0.010000  loss: 0.1664 (0.1875)  lesion-detection_performer-object_detection_loss_classifier: 0.0785 (0.0854)  lesion-detection_performer-object_detection_loss_box_reg: 0.0505 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0241 (0.0303)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0047)  time: 0.8396  data: 0.6396  max mem: 13299
# Epoch: [2]  [130/531]  eta: 0:05:37  lr: 0.010000  loss: 0.1881 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0825 (0.0851)  lesion-detection_performer-object_detection_loss_box_reg: 0.0633 (0.0672)  lesion-detection_performer-object_detection_loss_objectness: 0.0311 (0.0304)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0047)  time: 0.8374  data: 0.6366  max mem: 13299
# Epoch: [2]  [140/531]  eta: 0:05:29  lr: 0.010000  loss: 0.1701 (0.1869)  lesion-detection_performer-object_detection_loss_classifier: 0.0765 (0.0850)  lesion-detection_performer-object_detection_loss_box_reg: 0.0594 (0.0667)  lesion-detection_performer-object_detection_loss_objectness: 0.0298 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0047)  time: 0.8448  data: 0.6449  max mem: 13299
# Epoch: [2]  [150/531]  eta: 0:05:20  lr: 0.010000  loss: 0.1749 (0.1879)  lesion-detection_performer-object_detection_loss_classifier: 0.0767 (0.0856)  lesion-detection_performer-object_detection_loss_box_reg: 0.0594 (0.0670)  lesion-detection_performer-object_detection_loss_objectness: 0.0314 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0047)  time: 0.8382  data: 0.6411  max mem: 13299
# Epoch: [2]  [160/531]  eta: 0:05:11  lr: 0.010000  loss: 0.2052 (0.1882)  lesion-detection_performer-object_detection_loss_classifier: 0.0927 (0.0859)  lesion-detection_performer-object_detection_loss_box_reg: 0.0711 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0314 (0.0307)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0047 (0.0047)  time: 0.8222  data: 0.6259  max mem: 13299
# Epoch: [2]  [170/531]  eta: 0:05:03  lr: 0.010000  loss: 0.2003 (0.1887)  lesion-detection_performer-object_detection_loss_classifier: 0.0940 (0.0863)  lesion-detection_performer-object_detection_loss_box_reg: 0.0676 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0294 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.8348  data: 0.6357  max mem: 13299
# Epoch: [2]  [180/531]  eta: 0:04:55  lr: 0.010000  loss: 0.1656 (0.1873)  lesion-detection_performer-object_detection_loss_classifier: 0.0763 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0568 (0.0668)  lesion-detection_performer-object_detection_loss_objectness: 0.0204 (0.0301)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0033 (0.0046)  time: 0.8498  data: 0.6496  max mem: 13299
# Epoch: [2]  [190/531]  eta: 0:04:46  lr: 0.010000  loss: 0.1754 (0.1890)  lesion-detection_performer-object_detection_loss_classifier: 0.0764 (0.0863)  lesion-detection_performer-object_detection_loss_box_reg: 0.0703 (0.0678)  lesion-detection_performer-object_detection_loss_objectness: 0.0243 (0.0302)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0047)  time: 0.8441  data: 0.6442  max mem: 13299
# Epoch: [2]  [200/531]  eta: 0:04:38  lr: 0.010000  loss: 0.1726 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0721 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0565 (0.0670)  lesion-detection_performer-object_detection_loss_objectness: 0.0297 (0.0302)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0054 (0.0047)  time: 0.8393  data: 0.6385  max mem: 13299
# Epoch: [2]  [210/531]  eta: 0:04:30  lr: 0.010000  loss: 0.1726 (0.1890)  lesion-detection_performer-object_detection_loss_classifier: 0.0721 (0.0863)  lesion-detection_performer-object_detection_loss_box_reg: 0.0588 (0.0675)  lesion-detection_performer-object_detection_loss_objectness: 0.0284 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0051 (0.0047)  time: 0.8497  data: 0.6479  max mem: 13299
# Epoch: [2]  [220/531]  eta: 0:04:21  lr: 0.010000  loss: 0.1953 (0.1891)  lesion-detection_performer-object_detection_loss_classifier: 0.0884 (0.0865)  lesion-detection_performer-object_detection_loss_box_reg: 0.0714 (0.0676)  lesion-detection_performer-object_detection_loss_objectness: 0.0275 (0.0303)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0047)  time: 0.8461  data: 0.6462  max mem: 13299
# Epoch: [2]  [230/531]  eta: 0:04:13  lr: 0.010000  loss: 0.1950 (0.1894)  lesion-detection_performer-object_detection_loss_classifier: 0.0776 (0.0865)  lesion-detection_performer-object_detection_loss_box_reg: 0.0704 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0285 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0047)  time: 0.8332  data: 0.6369  max mem: 13299
# Epoch: [2]  [240/531]  eta: 0:04:04  lr: 0.010000  loss: 0.1490 (0.1880)  lesion-detection_performer-object_detection_loss_classifier: 0.0686 (0.0860)  lesion-detection_performer-object_detection_loss_box_reg: 0.0492 (0.0672)  lesion-detection_performer-object_detection_loss_objectness: 0.0271 (0.0302)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0046)  time: 0.8363  data: 0.6401  max mem: 13299
# Epoch: [2]  [250/531]  eta: 0:03:56  lr: 0.010000  loss: 0.1637 (0.1889)  lesion-detection_performer-object_detection_loss_classifier: 0.0770 (0.0864)  lesion-detection_performer-object_detection_loss_box_reg: 0.0516 (0.0674)  lesion-detection_performer-object_detection_loss_objectness: 0.0273 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0047)  time: 0.8558  data: 0.6567  max mem: 13299
# Epoch: [2]  [260/531]  eta: 0:03:48  lr: 0.010000  loss: 0.1694 (0.1894)  lesion-detection_performer-object_detection_loss_classifier: 0.0770 (0.0866)  lesion-detection_performer-object_detection_loss_box_reg: 0.0632 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0305 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0046)  time: 0.8713  data: 0.6676  max mem: 13299
# Epoch: [2]  [270/531]  eta: 0:03:40  lr: 0.010000  loss: 0.1694 (0.1897)  lesion-detection_performer-object_detection_loss_classifier: 0.0739 (0.0868)  lesion-detection_performer-object_detection_loss_box_reg: 0.0573 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0268 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0047)  time: 0.8705  data: 0.6644  max mem: 13299
# Epoch: [2]  [280/531]  eta: 0:03:32  lr: 0.010000  loss: 0.1635 (0.1901)  lesion-detection_performer-object_detection_loss_classifier: 0.0714 (0.0869)  lesion-detection_performer-object_detection_loss_box_reg: 0.0573 (0.0680)  lesion-detection_performer-object_detection_loss_objectness: 0.0253 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0047)  time: 0.8682  data: 0.6628  max mem: 13299
# Epoch: [2]  [290/531]  eta: 0:03:23  lr: 0.010000  loss: 0.1713 (0.1903)  lesion-detection_performer-object_detection_loss_classifier: 0.0685 (0.0871)  lesion-detection_performer-object_detection_loss_box_reg: 0.0591 (0.0679)  lesion-detection_performer-object_detection_loss_objectness: 0.0253 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0048)  time: 0.8758  data: 0.6682  max mem: 13299
# Epoch: [2]  [300/531]  eta: 0:03:16  lr: 0.010000  loss: 0.1806 (0.1902)  lesion-detection_performer-object_detection_loss_classifier: 0.0818 (0.0868)  lesion-detection_performer-object_detection_loss_box_reg: 0.0665 (0.0679)  lesion-detection_performer-object_detection_loss_objectness: 0.0287 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0043 (0.0048)  time: 0.9177  data: 0.7039  max mem: 13299
# Epoch: [2]  [310/531]  eta: 0:03:08  lr: 0.010000  loss: 0.1726 (0.1892)  lesion-detection_performer-object_detection_loss_classifier: 0.0791 (0.0863)  lesion-detection_performer-object_detection_loss_box_reg: 0.0530 (0.0674)  lesion-detection_performer-object_detection_loss_objectness: 0.0282 (0.0306)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0048)  time: 0.9672  data: 0.7492  max mem: 13299
# Epoch: [2]  [320/531]  eta: 0:03:01  lr: 0.010000  loss: 0.1757 (0.1897)  lesion-detection_performer-object_detection_loss_classifier: 0.0824 (0.0867)  lesion-detection_performer-object_detection_loss_box_reg: 0.0652 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0274 (0.0305)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0048)  time: 1.0524  data: 0.8328  max mem: 13299
# Epoch: [2]  [330/531]  eta: 0:02:53  lr: 0.010000  loss: 0.1757 (0.1892)  lesion-detection_performer-object_detection_loss_classifier: 0.0829 (0.0866)  lesion-detection_performer-object_detection_loss_box_reg: 0.0639 (0.0675)  lesion-detection_performer-object_detection_loss_objectness: 0.0245 (0.0304)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0047)  time: 1.0480  data: 0.8285  max mem: 13299
# Epoch: [2]  [340/531]  eta: 0:02:46  lr: 0.010000  loss: 0.1447 (0.1878)  lesion-detection_performer-object_detection_loss_classifier: 0.0672 (0.0861)  lesion-detection_performer-object_detection_loss_box_reg: 0.0472 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0228 (0.0301)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0027 (0.0047)  time: 1.0100  data: 0.7846  max mem: 13299
# Epoch: [2]  [350/531]  eta: 0:02:37  lr: 0.010000  loss: 0.1447 (0.1881)  lesion-detection_performer-object_detection_loss_classifier: 0.0672 (0.0862)  lesion-detection_performer-object_detection_loss_box_reg: 0.0475 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0219 (0.0301)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.9711  data: 0.7510  max mem: 13299
# Epoch: [2]  [360/531]  eta: 0:02:29  lr: 0.010000  loss: 0.1737 (0.1881)  lesion-detection_performer-object_detection_loss_classifier: 0.0811 (0.0863)  lesion-detection_performer-object_detection_loss_box_reg: 0.0589 (0.0673)  lesion-detection_performer-object_detection_loss_objectness: 0.0219 (0.0299)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0046)  time: 0.8949  data: 0.6840  max mem: 13299
# Epoch: [2]  [370/531]  eta: 0:02:20  lr: 0.010000  loss: 0.1737 (0.1883)  lesion-detection_performer-object_detection_loss_classifier: 0.0811 (0.0864)  lesion-detection_performer-object_detection_loss_box_reg: 0.0589 (0.0674)  lesion-detection_performer-object_detection_loss_objectness: 0.0203 (0.0299)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0046)  time: 0.8840  data: 0.6719  max mem: 13299
# Epoch: [2]  [380/531]  eta: 0:02:11  lr: 0.010000  loss: 0.1605 (0.1878)  lesion-detection_performer-object_detection_loss_classifier: 0.0696 (0.0862)  lesion-detection_performer-object_detection_loss_box_reg: 0.0536 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0238 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0046)  time: 0.8619  data: 0.6528  max mem: 13299
# Epoch: [2]  [390/531]  eta: 0:02:02  lr: 0.010000  loss: 0.1605 (0.1872)  lesion-detection_performer-object_detection_loss_classifier: 0.0696 (0.0860)  lesion-detection_performer-object_detection_loss_box_reg: 0.0521 (0.0668)  lesion-detection_performer-object_detection_loss_objectness: 0.0281 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0037 (0.0046)  time: 0.8556  data: 0.6471  max mem: 13299
# Epoch: [2]  [400/531]  eta: 0:01:54  lr: 0.010000  loss: 0.1539 (0.1866)  lesion-detection_performer-object_detection_loss_classifier: 0.0678 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0526 (0.0666)  lesion-detection_performer-object_detection_loss_objectness: 0.0229 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0046)  time: 0.8652  data: 0.6498  max mem: 13299
# Epoch: [2]  [410/531]  eta: 0:01:45  lr: 0.010000  loss: 0.1554 (0.1871)  lesion-detection_performer-object_detection_loss_classifier: 0.0734 (0.0858)  lesion-detection_performer-object_detection_loss_box_reg: 0.0629 (0.0670)  lesion-detection_performer-object_detection_loss_objectness: 0.0241 (0.0297)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0046 (0.0046)  time: 0.8682  data: 0.6530  max mem: 13299
# Epoch: [2]  [420/531]  eta: 0:01:36  lr: 0.010000  loss: 0.1751 (0.1868)  lesion-detection_performer-object_detection_loss_classifier: 0.0717 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0639 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0281 (0.0297)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0047 (0.0046)  time: 0.8687  data: 0.6604  max mem: 13299
# Epoch: [2]  [430/531]  eta: 0:01:27  lr: 0.010000  loss: 0.1588 (0.1867)  lesion-detection_performer-object_detection_loss_classifier: 0.0709 (0.0856)  lesion-detection_performer-object_detection_loss_box_reg: 0.0551 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0294 (0.0297)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0046)  time: 0.8682  data: 0.6615  max mem: 13299
# Epoch: [2]  [440/531]  eta: 0:01:19  lr: 0.010000  loss: 0.1725 (0.1873)  lesion-detection_performer-object_detection_loss_classifier: 0.0741 (0.0858)  lesion-detection_performer-object_detection_loss_box_reg: 0.0674 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0301 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0046)  time: 0.8684  data: 0.6604  max mem: 13299
# Epoch: [2]  [450/531]  eta: 0:01:10  lr: 0.010000  loss: 0.1888 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0849 (0.0858)  lesion-detection_performer-object_detection_loss_box_reg: 0.0759 (0.0672)  lesion-detection_performer-object_detection_loss_objectness: 0.0301 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.8723  data: 0.6632  max mem: 13299
# Epoch: [2]  [460/531]  eta: 0:01:01  lr: 0.010000  loss: 0.1888 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0832 (0.0858)  lesion-detection_performer-object_detection_loss_box_reg: 0.0765 (0.0672)  lesion-detection_performer-object_detection_loss_objectness: 0.0307 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0046)  time: 0.8697  data: 0.6583  max mem: 13299
# Epoch: [2]  [470/531]  eta: 0:00:53  lr: 0.010000  loss: 0.1674 (0.1870)  lesion-detection_performer-object_detection_loss_classifier: 0.0736 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0572 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0307 (0.0298)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0046 (0.0046)  time: 0.8953  data: 0.6823  max mem: 13299
# Epoch: [2]  [480/531]  eta: 0:00:44  lr: 0.010000  loss: 0.1674 (0.1874)  lesion-detection_performer-object_detection_loss_classifier: 0.0736 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0572 (0.0673)  lesion-detection_performer-object_detection_loss_objectness: 0.0262 (0.0297)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0054 (0.0046)  time: 0.9063  data: 0.6947  max mem: 13299
# Epoch: [2]  [490/531]  eta: 0:00:35  lr: 0.010000  loss: 0.1778 (0.1870)  lesion-detection_performer-object_detection_loss_classifier: 0.0824 (0.0856)  lesion-detection_performer-object_detection_loss_box_reg: 0.0636 (0.0672)  lesion-detection_performer-object_detection_loss_objectness: 0.0211 (0.0296)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0046)  time: 0.8946  data: 0.6842  max mem: 13299
# Epoch: [2]  [500/531]  eta: 0:00:27  lr: 0.010000  loss: 0.1568 (0.1868)  lesion-detection_performer-object_detection_loss_classifier: 0.0732 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0577 (0.0671)  lesion-detection_performer-object_detection_loss_objectness: 0.0232 (0.0296)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0046)  time: 0.8988  data: 0.6851  max mem: 13299
# Epoch: [2]  [510/531]  eta: 0:00:18  lr: 0.010000  loss: 0.1568 (0.1869)  lesion-detection_performer-object_detection_loss_classifier: 0.0732 (0.0855)  lesion-detection_performer-object_detection_loss_box_reg: 0.0573 (0.0673)  lesion-detection_performer-object_detection_loss_objectness: 0.0258 (0.0295)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0046)  time: 0.8995  data: 0.6831  max mem: 13299
# Epoch: [2]  [520/531]  eta: 0:00:09  lr: 0.010000  loss: 0.1956 (0.1877)  lesion-detection_performer-object_detection_loss_classifier: 0.0885 (0.0858)  lesion-detection_performer-object_detection_loss_box_reg: 0.0823 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0263 (0.0296)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0052 (0.0046)  time: 0.9086  data: 0.6950  max mem: 13299
# Epoch: [2]  [530/531]  eta: 0:00:00  lr: 0.010000  loss: 0.1939 (0.1873)  lesion-detection_performer-object_detection_loss_classifier: 0.0903 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0739 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0232 (0.0294)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0046)  time: 0.9021  data: 0.6865  max mem: 13299
# Epoch: [2] Total time: 0:07:44 (0.8753 s / it)
# Averaged stats: lr: 0.010000  loss: 0.1939 (0.1873)  lesion-detection_performer-object_detection_loss_classifier: 0.0903 (0.0857)  lesion-detection_performer-object_detection_loss_box_reg: 0.0739 (0.0677)  lesion-detection_performer-object_detection_loss_objectness: 0.0232 (0.0294)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.15s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.066
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.070
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.378

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_baseline_efficientnet_b5]========================================
# ModelSetup(name='lesion_dsetection_baseline_efficientnet_b5', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b5', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =========================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1898_test_lesion-detection_ap_0_2055_epoch5_03-17-2023 23-30-57_lesion_dsetection_baseline_efficientnet_b5]
# The final model has been saved to: [val_lesion-detection_ap_0_1441_test_lesion-detection_ap_0_1410_epoch24_03-18-2023 01-19-01_lesion_dsetection_baseline_efficientnet_b5]
#
# =========================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
