# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 10,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}

vgg16_args = {
    "backbone": "vgg16",
    "using_fpn": False,
}

regnet_y_8gf_args = {
    "backbone": "regnet_y_8gf",
    "using_fpn": False,
}


convnext_base_args = {
    "backbone": "convnext_base",
    "using_fpn": False,
}

# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_convnext_base",
        **lesion_detection_best_args,
        **convnext_base_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    ModelSetup(
        name="lesion_dsetection_baseline_convnext_base",
        **lesion_detection_best_args,
        **regnet_y_8gf_args,
        **small_model_args,
        **common_args,
        **without_fix_args,
    ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        # use Average Precision (Performance value) instead of loss in lr_scheduler.
        # val_loss = train_info.val_losses[-1]["loss"]
        val_performance_value = train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_performance_value)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resizeda
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [28] Done | It has took [170.03] min, Avg time: [364.36] sec/epoch | Estimate time for [50] epochs: [303.63] min | Epoch took [339] sec | Patience [10] |====================
# ====================Training model: [lesion_dsetection_baseline_convnext_base]====================
# ========================================For Training [lesion_dsetection_baseline_convnext_base]========================================
# ModelSetup(name='lesion_dsetection_baseline_convnext_base', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='regnet_y_8gf', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =======================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1954_test_lesion-detection_ap_0_1919_epoch18_03-22-2023 07-20-28_lesion_dsetection_baseline_convnext_base]
# The final model has been saved to: [val_lesion-detection_ap_0_1954_test_lesion-detection_ap_0_1919_epoch18_03-22-2023 07-20-28_lesion_dsetection_baseline_convnext_base]
#
# =======================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4362
# [lesion-detection_performer-object_detection_loss_classifier]: 0.3819
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.1734
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.2003
# backbone weights fix status: False
# Epoch: [29]  [  0/266]  eta: 0:04:10  lr: 0.010000  loss: 0.1004 (0.1004)  lesion-detection_performer-object_detection_loss_classifier: 0.0335 (0.0335)  lesion-detection_performer-object_detection_loss_box_reg: 0.0623 (0.0623)  lesion-detection_performer-object_detection_loss_objectness: 0.0012 (0.0012)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0034)  time: 0.9422  data: 0.5759  max mem: 20796
# Epoch: [29]  [ 10/266]  eta: 0:03:29  lr: 0.010000  loss: 0.0877 (0.0919)  lesion-detection_performer-object_detection_loss_classifier: 0.0335 (0.0325)  lesion-detection_performer-object_detection_loss_box_reg: 0.0511 (0.0545)  lesion-detection_performer-object_detection_loss_objectness: 0.0027 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0021)  time: 0.8196  data: 0.6100  max mem: 20796
# Epoch: [29]  [ 20/266]  eta: 0:03:15  lr: 0.010000  loss: 0.0759 (0.0786)  lesion-detection_performer-object_detection_loss_classifier: 0.0260 (0.0290)  lesion-detection_performer-object_detection_loss_box_reg: 0.0410 (0.0454)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.7879  data: 0.5939  max mem: 20796
# Epoch: [29]  [ 30/266]  eta: 0:03:08  lr: 0.010000  loss: 0.0810 (0.0896)  lesion-detection_performer-object_detection_loss_classifier: 0.0312 (0.0324)  lesion-detection_performer-object_detection_loss_box_reg: 0.0410 (0.0520)  lesion-detection_performer-object_detection_loss_objectness: 0.0026 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0020)  time: 0.7895  data: 0.5952  max mem: 20796
# Epoch: [29]  [ 40/266]  eta: 0:03:02  lr: 0.010000  loss: 0.0936 (0.0865)  lesion-detection_performer-object_detection_loss_classifier: 0.0334 (0.0318)  lesion-detection_performer-object_detection_loss_box_reg: 0.0524 (0.0497)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.8173  data: 0.6233  max mem: 20796
# Epoch: [29]  [ 50/266]  eta: 0:02:53  lr: 0.010000  loss: 0.0799 (0.0860)  lesion-detection_performer-object_detection_loss_classifier: 0.0310 (0.0318)  lesion-detection_performer-object_detection_loss_box_reg: 0.0464 (0.0494)  lesion-detection_performer-object_detection_loss_objectness: 0.0017 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.8061  data: 0.6141  max mem: 20796
# Epoch: [29]  [ 60/266]  eta: 0:02:44  lr: 0.010000  loss: 0.0853 (0.0861)  lesion-detection_performer-object_detection_loss_classifier: 0.0293 (0.0317)  lesion-detection_performer-object_detection_loss_box_reg: 0.0500 (0.0495)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0020)  time: 0.7897  data: 0.5968  max mem: 20796
# Epoch: [29]  [ 70/266]  eta: 0:02:37  lr: 0.010000  loss: 0.0853 (0.0878)  lesion-detection_performer-object_detection_loss_classifier: 0.0292 (0.0322)  lesion-detection_performer-object_detection_loss_box_reg: 0.0514 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.7978  data: 0.6030  max mem: 20796
# Epoch: [29]  [ 80/266]  eta: 0:02:29  lr: 0.010000  loss: 0.0892 (0.0883)  lesion-detection_performer-object_detection_loss_classifier: 0.0298 (0.0323)  lesion-detection_performer-object_detection_loss_box_reg: 0.0473 (0.0510)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.8092  data: 0.6143  max mem: 20796
# Epoch: [29]  [ 90/266]  eta: 0:02:21  lr: 0.010000  loss: 0.0798 (0.0879)  lesion-detection_performer-object_detection_loss_classifier: 0.0274 (0.0324)  lesion-detection_performer-object_detection_loss_box_reg: 0.0478 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0024 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.8092  data: 0.6147  max mem: 20796
# Epoch: [29]  [100/266]  eta: 0:02:12  lr: 0.010000  loss: 0.0838 (0.0877)  lesion-detection_performer-object_detection_loss_classifier: 0.0274 (0.0322)  lesion-detection_performer-object_detection_loss_box_reg: 0.0480 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0020 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.7901  data: 0.5950  max mem: 20796
# Epoch: [29]  [110/266]  eta: 0:02:04  lr: 0.010000  loss: 0.0879 (0.0892)  lesion-detection_performer-object_detection_loss_classifier: 0.0319 (0.0325)  lesion-detection_performer-object_detection_loss_box_reg: 0.0515 (0.0516)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0021)  time: 0.7836  data: 0.5888  max mem: 20796
# Epoch: [29]  [120/266]  eta: 0:01:56  lr: 0.010000  loss: 0.0851 (0.0882)  lesion-detection_performer-object_detection_loss_classifier: 0.0306 (0.0322)  lesion-detection_performer-object_detection_loss_box_reg: 0.0520 (0.0510)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.7966  data: 0.6026  max mem: 20796
# Epoch: [29]  [130/266]  eta: 0:01:48  lr: 0.010000  loss: 0.0748 (0.0881)  lesion-detection_performer-object_detection_loss_classifier: 0.0294 (0.0323)  lesion-detection_performer-object_detection_loss_box_reg: 0.0452 (0.0509)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.7943  data: 0.5999  max mem: 20796
# Epoch: [29]  [140/266]  eta: 0:01:40  lr: 0.010000  loss: 0.0897 (0.0875)  lesion-detection_performer-object_detection_loss_classifier: 0.0295 (0.0322)  lesion-detection_performer-object_detection_loss_box_reg: 0.0497 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.7955  data: 0.6006  max mem: 20796
# Epoch: [29]  [150/266]  eta: 0:01:32  lr: 0.010000  loss: 0.0908 (0.0879)  lesion-detection_performer-object_detection_loss_classifier: 0.0340 (0.0325)  lesion-detection_performer-object_detection_loss_box_reg: 0.0497 (0.0504)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.8096  data: 0.6142  max mem: 20796
# Epoch: [29]  [160/266]  eta: 0:01:24  lr: 0.010000  loss: 0.1005 (0.0886)  lesion-detection_performer-object_detection_loss_classifier: 0.0383 (0.0329)  lesion-detection_performer-object_detection_loss_box_reg: 0.0531 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.7894  data: 0.5947  max mem: 20796
# Epoch: [29]  [170/266]  eta: 0:01:16  lr: 0.010000  loss: 0.0947 (0.0891)  lesion-detection_performer-object_detection_loss_classifier: 0.0383 (0.0333)  lesion-detection_performer-object_detection_loss_box_reg: 0.0541 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.7824  data: 0.5887  max mem: 20796
# Epoch: [29]  [180/266]  eta: 0:01:08  lr: 0.010000  loss: 0.0816 (0.0887)  lesion-detection_performer-object_detection_loss_classifier: 0.0314 (0.0331)  lesion-detection_performer-object_detection_loss_box_reg: 0.0438 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.8049  data: 0.6102  max mem: 20796
# Epoch: [29]  [190/266]  eta: 0:01:00  lr: 0.010000  loss: 0.0846 (0.0895)  lesion-detection_performer-object_detection_loss_classifier: 0.0285 (0.0335)  lesion-detection_performer-object_detection_loss_box_reg: 0.0501 (0.0510)  lesion-detection_performer-object_detection_loss_objectness: 0.0029 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.8018  data: 0.6058  max mem: 20796
# Epoch: [29]  [200/266]  eta: 0:00:52  lr: 0.010000  loss: 0.1020 (0.0900)  lesion-detection_performer-object_detection_loss_classifier: 0.0375 (0.0337)  lesion-detection_performer-object_detection_loss_box_reg: 0.0547 (0.0512)  lesion-detection_performer-object_detection_loss_objectness: 0.0024 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.7942  data: 0.5986  max mem: 20796
# Epoch: [29]  [210/266]  eta: 0:00:44  lr: 0.010000  loss: 0.0823 (0.0897)  lesion-detection_performer-object_detection_loss_classifier: 0.0302 (0.0336)  lesion-detection_performer-object_detection_loss_box_reg: 0.0485 (0.0510)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.7956  data: 0.6012  max mem: 20796
# Epoch: [29]  [220/266]  eta: 0:00:36  lr: 0.010000  loss: 0.0823 (0.0900)  lesion-detection_performer-object_detection_loss_classifier: 0.0321 (0.0339)  lesion-detection_performer-object_detection_loss_box_reg: 0.0471 (0.0510)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.8080  data: 0.6129  max mem: 20796
# Epoch: [29]  [230/266]  eta: 0:00:28  lr: 0.010000  loss: 0.0874 (0.0899)  lesion-detection_performer-object_detection_loss_classifier: 0.0335 (0.0338)  lesion-detection_performer-object_detection_loss_box_reg: 0.0500 (0.0511)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.8087  data: 0.6126  max mem: 20796
# Epoch: [29]  [240/266]  eta: 0:00:20  lr: 0.010000  loss: 0.0754 (0.0893)  lesion-detection_performer-object_detection_loss_classifier: 0.0276 (0.0335)  lesion-detection_performer-object_detection_loss_box_reg: 0.0448 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.8089  data: 0.6129  max mem: 20796
# Epoch: [29]  [250/266]  eta: 0:00:12  lr: 0.010000  loss: 0.0754 (0.0888)  lesion-detection_performer-object_detection_loss_classifier: 0.0298 (0.0334)  lesion-detection_performer-object_detection_loss_box_reg: 0.0417 (0.0504)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.8083  data: 0.6120  max mem: 20796
# Epoch: [29]  [260/266]  eta: 0:00:04  lr: 0.010000  loss: 0.0815 (0.0890)  lesion-detection_performer-object_detection_loss_classifier: 0.0317 (0.0334)  lesion-detection_performer-object_detection_loss_box_reg: 0.0521 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.7921  data: 0.5957  max mem: 20796
# Epoch: [29]  [265/266]  eta: 0:00:00  lr: 0.010000  loss: 0.0815 (0.0892)  lesion-detection_performer-object_detection_loss_classifier: 0.0317 (0.0335)  lesion-detection_performer-object_detection_loss_box_reg: 0.0521 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.7756  data: 0.5847  max mem: 20796
# Epoch: [29] Total time: 0:03:32 (0.7975 s / it)
# Averaged stats: lr: 0.010000  loss: 0.0815 (0.0892)  lesion-detection_performer-object_detection_loss_classifier: 0.0317 (0.0335)  lesion-detection_performer-object_detection_loss_box_reg: 0.0521 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.280
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.282
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.193
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.409
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.409
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.409
# Evaluation:  [ 0/57]  eta: 0:01:01  loss: 0.2671 (0.2671)  lesion-detection_performer-object_detection_loss_classifier: 0.0944 (0.0944)  lesion-detection_performer-object_detection_loss_box_reg: 0.0640 (0.0640)  lesion-detection_performer-object_detection_loss_objectness: 0.1004 (0.1004)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0082 (0.0082)  model_time: 1679437312.0000 (1679437250.2960)  evaluator_time: 0.0000 (0.0000)  time: 1.0800  data: 1.0150  max mem: 20796
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2333 (0.2593)  lesion-detection_performer-object_detection_loss_classifier: 0.1125 (0.1281)  lesion-detection_performer-object_detection_loss_box_reg: 0.0577 (0.0700)  lesion-detection_performer-object_detection_loss_objectness: 0.0506 (0.0559)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0051 (0.0053)  model_time: 1679437312.0000 (1679437281.7772)  evaluator_time: 0.0000 (0.0000)  time: 1.1136  data: 0.9653  max mem: 20796
# Evaluation: Total time: 0:01:04 (1.1230 s / it)
# Averaged stats: loss: 0.2333 (0.2593)  lesion-detection_performer-object_detection_loss_classifier: 0.1125 (0.1281)  lesion-detection_performer-object_detection_loss_box_reg: 0.0577 (0.0700)  lesion-detection_performer-object_detection_loss_objectness: 0.0506 (0.0559)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0051 (0.0053)  model_time: 1679437312.0000 (1679437281.7772)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.147
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.198
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.390
# Evaluation:  [ 0/57]  eta: 0:00:56  loss: 0.1515 (0.1515)  lesion-detection_performer-object_detection_loss_classifier: 0.0459 (0.0459)  lesion-detection_performer-object_detection_loss_box_reg: 0.0165 (0.0165)  lesion-detection_performer-object_detection_loss_objectness: 0.0845 (0.0845)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0046 (0.0046)  model_time: 1679437312.0000 (1679437314.2832)  evaluator_time: 0.0000 (0.0000)  time: 0.9947  data: 0.9357  max mem: 20796
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2159 (0.2431)  lesion-detection_performer-object_detection_loss_classifier: 0.1075 (0.1220)  lesion-detection_performer-object_detection_loss_box_reg: 0.0607 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0394 (0.0490)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0051)  model_time: 1679437312.0000 (1679437345.6498)  evaluator_time: 0.0000 (0.0000)  time: 1.0566  data: 0.9333  max mem: 20796
# Evaluation: Total time: 0:01:02 (1.1037 s / it)
# Averaged stats: loss: 0.2159 (0.2431)  lesion-detection_performer-object_detection_loss_classifier: 0.1075 (0.1220)  lesion-detection_performer-object_detection_loss_box_reg: 0.0607 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0394 (0.0490)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0044 (0.0051)  model_time: 1679437312.0000 (1679437345.6498)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.152
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.211
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.401
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.401
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.401
# ====================| EarlyStop | Epoch [29] Done | It has took [175.70] min, Avg time: [363.52] sec/epoch | Estimate time for [50] epochs: [302.93] min | Epoch took [339] sec |====================
# ====================| Training Done, start testing! | [29] Epochs Training time: [10542] seconds, Avg time / Epoch: [363.51724137931035] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_1954_test_lesion-detection_ap_0_1919_epoch18_03-22-2023 07-20-28_lesion_dsetection_baseline_convnext_base]====================
# Evaluation:  [ 0/57]  eta: 0:00:50  loss: 0.0907 (0.0907)  lesion-detection_performer-object_detection_loss_classifier: 0.0455 (0.0455)  lesion-detection_performer-object_detection_loss_box_reg: 0.0249 (0.0249)  lesion-detection_performer-object_detection_loss_objectness: 0.0184 (0.0184)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  model_time: 1679437440.0000 (1679437377.1308)  evaluator_time: 0.0000 (0.0000)  time: 0.8820  data: 0.8145  max mem: 20796
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2524 (0.2430)  lesion-detection_performer-object_detection_loss_classifier: 0.1218 (0.1214)  lesion-detection_performer-object_detection_loss_box_reg: 0.0659 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0442 (0.0496)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0049 (0.0051)  model_time: 1679437440.0000 (1679437408.2733)  evaluator_time: 0.0000 (0.0000)  time: 1.0855  data: 0.9610  max mem: 20796
# Evaluation: Total time: 0:01:02 (1.1014 s / it)
# Averaged stats: loss: 0.2524 (0.2430)  lesion-detection_performer-object_detection_loss_classifier: 0.1218 (0.1214)  lesion-detection_performer-object_detection_loss_box_reg: 0.0659 (0.0669)  lesion-detection_performer-object_detection_loss_objectness: 0.0442 (0.0496)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0049 (0.0051)  model_time: 1679437440.0000 (1679437408.2733)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.153
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.154
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.208
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.403
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.403
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.403
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1471_test_lesion-detection_ap_0_1530_epoch29_03-22-2023 08-23-59_lesion_dsetection_baseline_convnext_base]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_convnext_base]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_convnext_base', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='convnext_base', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ============================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2610_test_lesion-detection_ap_0_2548_epoch22_03-22-2023 02-55-37_lesion_dsetection_with_fixation_convnext_base]
# The final model has been saved to: [val_lesion-detection_ap_0_2057_test_lesion-detection_ap_0_2135_epoch33_03-22-2023 05-27-11_lesion_dsetection_with_fixation_convnext_base]
#
# ============================================================================================================================================
# ========================================For Training [lesion_dsetection_baseline_convnext_base]========================================
# ModelSetup(name='lesion_dsetection_baseline_convnext_base', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='regnet_y_8gf', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =======================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1954_test_lesion-detection_ap_0_1919_epoch18_03-22-2023 07-20-28_lesion_dsetection_baseline_convnext_base]
# The final model has been saved to: [val_lesion-detection_ap_0_1471_test_lesion-detection_ap_0_1530_epoch29_03-22-2023 08-23-59_lesion_dsetection_baseline_convnext_base]
#
# =======================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
