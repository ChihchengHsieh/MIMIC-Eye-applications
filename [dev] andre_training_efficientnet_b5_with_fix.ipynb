# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 4,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 20,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}
# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_efficientnet_b5",
        **lesion_detection_best_args,
        **efficientnet_b5_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    # ModelSetup(
    #     name="lesion_dsetection_baseline_efficientnet_b5",
    #     **lesion_detection_best_args,
    #     **efficientnet_b5_args,
    #     **small_model_args,
    #     **common_args,
    #     **without_fix_args,
    # ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        val_loss = train_info.val_losses[-1]["loss"]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_loss)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resized
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [23] Done | It has took [387.60] min, Avg time: [1011.13] sec/epoch | Estimate time for [50] epochs: [842.61] min | Epoch took [970] sec | Patience [20] |====================
# ====================Training model: [lesion_dsetection_with_fixation_efficientnet_b5]====================
# ========================================For Training [lesion_dsetection_with_fixation_efficientnet_b5]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_efficientnet_b5', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b5', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=4, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==============================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2117_test_lesion-detection_ap_0_2190_epoch8_03-18-2023 12-29-20_lesion_dsetection_with_fixation_efficientnet_b5]
# The final model has been saved to: [val_lesion-detection_ap_0_2117_test_lesion-detection_ap_0_2190_epoch8_03-18-2023 12-29-20_lesion_dsetection_with_fixation_efficientnet_b5]
#
# ==============================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.5205
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4224
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.3335
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.2035
# backbone weights fix status: False
# backbone weights fix status: False
# Epoch: [24]  [  0/531]  eta: 0:10:17  lr: 0.010000  loss: 0.0792 (0.0792)  lesion-detection_performer-object_detection_loss_classifier: 0.0210 (0.0210)  lesion-detection_performer-object_detection_loss_box_reg: 0.0544 (0.0544)  lesion-detection_performer-object_detection_loss_objectness: 0.0003 (0.0003)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0035)  time: 1.1632  data: 0.7882  max mem: 13299
# Epoch: [24]  [ 10/531]  eta: 0:09:24  lr: 0.010000  loss: 0.1006 (0.0962)  lesion-detection_performer-object_detection_loss_classifier: 0.0365 (0.0343)  lesion-detection_performer-object_detection_loss_box_reg: 0.0554 (0.0565)  lesion-detection_performer-object_detection_loss_objectness: 0.0020 (0.0021)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0033)  time: 1.0844  data: 0.7788  max mem: 13299
# Epoch: [24]  [ 20/531]  eta: 0:09:23  lr: 0.010000  loss: 0.0819 (0.0869)  lesion-detection_performer-object_detection_loss_classifier: 0.0279 (0.0311)  lesion-detection_performer-object_detection_loss_box_reg: 0.0421 (0.0495)  lesion-detection_performer-object_detection_loss_objectness: 0.0022 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0034)  time: 1.1000  data: 0.7929  max mem: 13299
# Epoch: [24]  [ 30/531]  eta: 0:08:59  lr: 0.010000  loss: 0.0590 (0.0826)  lesion-detection_performer-object_detection_loss_classifier: 0.0208 (0.0296)  lesion-detection_performer-object_detection_loss_box_reg: 0.0336 (0.0468)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0033)  time: 1.0742  data: 0.7721  max mem: 13299
# Epoch: [24]  [ 40/531]  eta: 0:08:45  lr: 0.010000  loss: 0.0684 (0.0824)  lesion-detection_performer-object_detection_loss_classifier: 0.0216 (0.0286)  lesion-detection_performer-object_detection_loss_box_reg: 0.0397 (0.0477)  lesion-detection_performer-object_detection_loss_objectness: 0.0020 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0032)  time: 1.0365  data: 0.7431  max mem: 13299
# Epoch: [24]  [ 50/531]  eta: 0:08:41  lr: 0.010000  loss: 0.0729 (0.0828)  lesion-detection_performer-object_detection_loss_classifier: 0.0256 (0.0286)  lesion-detection_performer-object_detection_loss_box_reg: 0.0457 (0.0481)  lesion-detection_performer-object_detection_loss_objectness: 0.0017 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0034)  time: 1.0942  data: 0.7804  max mem: 13299
# Epoch: [24]  [ 60/531]  eta: 0:08:34  lr: 0.010000  loss: 0.0816 (0.0837)  lesion-detection_performer-object_detection_loss_classifier: 0.0265 (0.0289)  lesion-detection_performer-object_detection_loss_box_reg: 0.0507 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0013 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0033)  time: 1.1353  data: 0.7977  max mem: 13299
# Epoch: [24]  [ 70/531]  eta: 0:08:15  lr: 0.010000  loss: 0.0779 (0.0846)  lesion-detection_performer-object_detection_loss_classifier: 0.0265 (0.0290)  lesion-detection_performer-object_detection_loss_box_reg: 0.0507 (0.0495)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0033)  time: 1.0471  data: 0.7460  max mem: 13299
# Epoch: [24]  [ 80/531]  eta: 0:08:00  lr: 0.010000  loss: 0.0755 (0.0835)  lesion-detection_performer-object_detection_loss_classifier: 0.0235 (0.0284)  lesion-detection_performer-object_detection_loss_box_reg: 0.0483 (0.0492)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0032)  time: 0.9862  data: 0.7286  max mem: 13299
# Epoch: [24]  [ 90/531]  eta: 0:07:54  lr: 0.010000  loss: 0.0639 (0.0822)  lesion-detection_performer-object_detection_loss_classifier: 0.0191 (0.0279)  lesion-detection_performer-object_detection_loss_box_reg: 0.0407 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0014 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0031)  time: 1.0792  data: 0.7844  max mem: 13299
# Epoch: [24]  [100/531]  eta: 0:07:50  lr: 0.010000  loss: 0.0670 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0227 (0.0275)  lesion-detection_performer-object_detection_loss_box_reg: 0.0338 (0.0479)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0031)  time: 1.1919  data: 0.8462  max mem: 13299
# Epoch: [24]  [110/531]  eta: 0:07:42  lr: 0.010000  loss: 0.0670 (0.0815)  lesion-detection_performer-object_detection_loss_classifier: 0.0227 (0.0276)  lesion-detection_performer-object_detection_loss_box_reg: 0.0338 (0.0480)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0031)  time: 1.2035  data: 0.8647  max mem: 13299
# Epoch: [24]  [120/531]  eta: 0:07:31  lr: 0.010000  loss: 0.0752 (0.0832)  lesion-detection_performer-object_detection_loss_classifier: 0.0262 (0.0279)  lesion-detection_performer-object_detection_loss_box_reg: 0.0423 (0.0494)  lesion-detection_performer-object_detection_loss_objectness: 0.0017 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.1404  data: 0.8198  max mem: 13299
# Epoch: [24]  [130/531]  eta: 0:07:22  lr: 0.010000  loss: 0.0671 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0198 (0.0271)  lesion-detection_performer-object_detection_loss_box_reg: 0.0423 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0032)  time: 1.1290  data: 0.8018  max mem: 13299
# Epoch: [24]  [140/531]  eta: 0:07:10  lr: 0.010000  loss: 0.0652 (0.0806)  lesion-detection_performer-object_detection_loss_classifier: 0.0171 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0424 (0.0481)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0032)  time: 1.1185  data: 0.8058  max mem: 13299
# Epoch: [24]  [150/531]  eta: 0:07:01  lr: 0.010000  loss: 0.0692 (0.0801)  lesion-detection_performer-object_detection_loss_classifier: 0.0257 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0448 (0.0478)  lesion-detection_performer-object_detection_loss_objectness: 0.0014 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0032)  time: 1.1199  data: 0.8100  max mem: 13299
# Epoch: [24]  [160/531]  eta: 0:06:51  lr: 0.010000  loss: 0.0764 (0.0798)  lesion-detection_performer-object_detection_loss_classifier: 0.0260 (0.0265)  lesion-detection_performer-object_detection_loss_box_reg: 0.0451 (0.0476)  lesion-detection_performer-object_detection_loss_objectness: 0.0007 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.1609  data: 0.8205  max mem: 13299
# Epoch: [24]  [170/531]  eta: 0:06:42  lr: 0.010000  loss: 0.0773 (0.0808)  lesion-detection_performer-object_detection_loss_classifier: 0.0265 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0494 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0012 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.1827  data: 0.8296  max mem: 13299
# Epoch: [24]  [180/531]  eta: 0:06:33  lr: 0.010000  loss: 0.0636 (0.0795)  lesion-detection_performer-object_detection_loss_classifier: 0.0194 (0.0263)  lesion-detection_performer-object_detection_loss_box_reg: 0.0425 (0.0477)  lesion-detection_performer-object_detection_loss_objectness: 0.0014 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0031)  time: 1.2156  data: 0.8687  max mem: 13299
# Epoch: [24]  [190/531]  eta: 0:06:22  lr: 0.010000  loss: 0.0729 (0.0807)  lesion-detection_performer-object_detection_loss_classifier: 0.0224 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0454 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0032)  time: 1.1776  data: 0.8381  max mem: 13299
# Epoch: [24]  [200/531]  eta: 0:06:13  lr: 0.010000  loss: 0.0848 (0.0808)  lesion-detection_performer-object_detection_loss_classifier: 0.0310 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0478 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0045 (0.0032)  time: 1.1856  data: 0.8404  max mem: 13299
# Epoch: [24]  [210/531]  eta: 0:06:01  lr: 0.010000  loss: 0.0691 (0.0808)  lesion-detection_performer-object_detection_loss_classifier: 0.0247 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0456 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0011 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0037 (0.0032)  time: 1.1856  data: 0.8432  max mem: 13299
# Epoch: [24]  [220/531]  eta: 0:05:51  lr: 0.010000  loss: 0.0723 (0.0807)  lesion-detection_performer-object_detection_loss_classifier: 0.0247 (0.0266)  lesion-detection_performer-object_detection_loss_box_reg: 0.0473 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0011 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0032)  time: 1.1676  data: 0.8093  max mem: 13299
# Epoch: [24]  [230/531]  eta: 0:05:40  lr: 0.010000  loss: 0.0723 (0.0801)  lesion-detection_performer-object_detection_loss_classifier: 0.0221 (0.0264)  lesion-detection_performer-object_detection_loss_box_reg: 0.0463 (0.0480)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0031)  time: 1.1833  data: 0.8412  max mem: 13299
# Epoch: [24]  [240/531]  eta: 0:05:29  lr: 0.010000  loss: 0.0688 (0.0808)  lesion-detection_performer-object_detection_loss_classifier: 0.0221 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0400 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.1478  data: 0.8480  max mem: 13299
# Epoch: [24]  [250/531]  eta: 0:05:19  lr: 0.010000  loss: 0.0906 (0.0815)  lesion-detection_performer-object_detection_loss_classifier: 0.0280 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0605 (0.0489)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0032)  time: 1.1808  data: 0.8442  max mem: 13299
# Epoch: [24]  [260/531]  eta: 0:05:08  lr: 0.010000  loss: 0.0830 (0.0819)  lesion-detection_performer-object_detection_loss_classifier: 0.0231 (0.0269)  lesion-detection_performer-object_detection_loss_box_reg: 0.0528 (0.0493)  lesion-detection_performer-object_detection_loss_objectness: 0.0024 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0032)  time: 1.2061  data: 0.8464  max mem: 13299
# Epoch: [24]  [270/531]  eta: 0:04:57  lr: 0.010000  loss: 0.0595 (0.0818)  lesion-detection_performer-object_detection_loss_classifier: 0.0205 (0.0269)  lesion-detection_performer-object_detection_loss_box_reg: 0.0415 (0.0491)  lesion-detection_performer-object_detection_loss_objectness: 0.0017 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0032)  time: 1.1701  data: 0.8312  max mem: 13299
# Epoch: [24]  [280/531]  eta: 0:04:45  lr: 0.010000  loss: 0.0574 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0162 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0357 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0008 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0032)  time: 1.1444  data: 0.8137  max mem: 13299
# Epoch: [24]  [290/531]  eta: 0:04:35  lr: 0.010000  loss: 0.0614 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0203 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0376 (0.0487)  lesion-detection_performer-object_detection_loss_objectness: 0.0012 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0015 (0.0031)  time: 1.1867  data: 0.8439  max mem: 13299
# Epoch: [24]  [300/531]  eta: 0:04:24  lr: 0.010000  loss: 0.0726 (0.0817)  lesion-detection_performer-object_detection_loss_classifier: 0.0232 (0.0269)  lesion-detection_performer-object_detection_loss_box_reg: 0.0419 (0.0491)  lesion-detection_performer-object_detection_loss_objectness: 0.0013 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0031)  time: 1.2078  data: 0.8588  max mem: 13299
# Epoch: [24]  [310/531]  eta: 0:04:12  lr: 0.010000  loss: 0.0761 (0.0815)  lesion-detection_performer-object_detection_loss_classifier: 0.0232 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0442 (0.0490)  lesion-detection_performer-object_detection_loss_objectness: 0.0012 (0.0025)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0031)  time: 1.1577  data: 0.8265  max mem: 13299
# Epoch: [24]  [320/531]  eta: 0:04:01  lr: 0.010000  loss: 0.0747 (0.0817)  lesion-detection_performer-object_detection_loss_classifier: 0.0240 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0442 (0.0491)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0026)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0031)  time: 1.1534  data: 0.8266  max mem: 13299
# Epoch: [24]  [330/531]  eta: 0:03:50  lr: 0.010000  loss: 0.0747 (0.0813)  lesion-detection_performer-object_detection_loss_classifier: 0.0240 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0395 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.1725  data: 0.8355  max mem: 13299
# Epoch: [24]  [340/531]  eta: 0:03:38  lr: 0.010000  loss: 0.0551 (0.0809)  lesion-detection_performer-object_detection_loss_classifier: 0.0169 (0.0265)  lesion-detection_performer-object_detection_loss_box_reg: 0.0302 (0.0486)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0031)  time: 1.1746  data: 0.8337  max mem: 13299
# Epoch: [24]  [350/531]  eta: 0:03:27  lr: 0.010000  loss: 0.0728 (0.0813)  lesion-detection_performer-object_detection_loss_classifier: 0.0247 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0399 (0.0487)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0032 (0.0031)  time: 1.1616  data: 0.8263  max mem: 13299
# Epoch: [24]  [360/531]  eta: 0:03:15  lr: 0.010000  loss: 0.0762 (0.0814)  lesion-detection_performer-object_detection_loss_classifier: 0.0308 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0412 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0032 (0.0031)  time: 1.1301  data: 0.8048  max mem: 13299
# Epoch: [24]  [370/531]  eta: 0:03:04  lr: 0.010000  loss: 0.0758 (0.0813)  lesion-detection_performer-object_detection_loss_classifier: 0.0279 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0421 (0.0487)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0031)  time: 1.1375  data: 0.8120  max mem: 13299
# Epoch: [24]  [380/531]  eta: 0:02:52  lr: 0.010000  loss: 0.0661 (0.0807)  lesion-detection_performer-object_detection_loss_classifier: 0.0201 (0.0266)  lesion-detection_performer-object_detection_loss_box_reg: 0.0414 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0031)  time: 1.1528  data: 0.8237  max mem: 13299
# Epoch: [24]  [390/531]  eta: 0:02:41  lr: 0.010000  loss: 0.0544 (0.0806)  lesion-detection_performer-object_detection_loss_classifier: 0.0172 (0.0265)  lesion-detection_performer-object_detection_loss_box_reg: 0.0324 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0031)  time: 1.1759  data: 0.8449  max mem: 13299
# Epoch: [24]  [400/531]  eta: 0:02:30  lr: 0.010000  loss: 0.0728 (0.0805)  lesion-detection_performer-object_detection_loss_classifier: 0.0235 (0.0265)  lesion-detection_performer-object_detection_loss_box_reg: 0.0423 (0.0482)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0031)  time: 1.1604  data: 0.8374  max mem: 13299
# Epoch: [24]  [410/531]  eta: 0:02:18  lr: 0.010000  loss: 0.0908 (0.0814)  lesion-detection_performer-object_detection_loss_classifier: 0.0314 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0518 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.1738  data: 0.8273  max mem: 13299
# Epoch: [24]  [420/531]  eta: 0:02:07  lr: 0.010000  loss: 0.0823 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0299 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0518 (0.0486)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0031)  time: 1.2207  data: 0.8522  max mem: 13299
# Epoch: [24]  [430/531]  eta: 0:01:56  lr: 0.010000  loss: 0.0785 (0.0815)  lesion-detection_performer-object_detection_loss_classifier: 0.0266 (0.0269)  lesion-detection_performer-object_detection_loss_box_reg: 0.0412 (0.0487)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0033 (0.0031)  time: 1.2332  data: 0.8577  max mem: 13299
# Epoch: [24]  [440/531]  eta: 0:01:45  lr: 0.010000  loss: 0.0800 (0.0813)  lesion-detection_performer-object_detection_loss_classifier: 0.0282 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0464 (0.0486)  lesion-detection_performer-object_detection_loss_objectness: 0.0013 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0033 (0.0031)  time: 1.2632  data: 0.8739  max mem: 13299
# Epoch: [24]  [450/531]  eta: 0:01:33  lr: 0.010000  loss: 0.0700 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0209 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0369 (0.0486)  lesion-detection_performer-object_detection_loss_objectness: 0.0011 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0031)  time: 1.3444  data: 0.9159  max mem: 13299
# Epoch: [24]  [460/531]  eta: 0:01:22  lr: 0.010000  loss: 0.0529 (0.0811)  lesion-detection_performer-object_detection_loss_classifier: 0.0167 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0369 (0.0485)  lesion-detection_performer-object_detection_loss_objectness: 0.0011 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0031)  time: 1.4352  data: 0.9581  max mem: 13299
# Epoch: [24]  [470/531]  eta: 0:01:11  lr: 0.010000  loss: 0.0686 (0.0811)  lesion-detection_performer-object_detection_loss_classifier: 0.0236 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0357 (0.0485)  lesion-detection_performer-object_detection_loss_objectness: 0.0011 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.4078  data: 0.9358  max mem: 13299
# Epoch: [24]  [480/531]  eta: 0:00:59  lr: 0.010000  loss: 0.0790 (0.0812)  lesion-detection_performer-object_detection_loss_classifier: 0.0295 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0376 (0.0485)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0031)  time: 1.3561  data: 0.8976  max mem: 13299
# Epoch: [24]  [490/531]  eta: 0:00:48  lr: 0.010000  loss: 0.0806 (0.0811)  lesion-detection_performer-object_detection_loss_classifier: 0.0297 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0405 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.3619  data: 0.8929  max mem: 13299
# Epoch: [24]  [500/531]  eta: 0:00:36  lr: 0.010000  loss: 0.0806 (0.0811)  lesion-detection_performer-object_detection_loss_classifier: 0.0302 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0432 (0.0484)  lesion-detection_performer-object_detection_loss_objectness: 0.0019 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.3827  data: 0.8938  max mem: 13299
# Epoch: [24]  [510/531]  eta: 0:00:24  lr: 0.010000  loss: 0.0649 (0.0806)  lesion-detection_performer-object_detection_loss_classifier: 0.0204 (0.0267)  lesion-detection_performer-object_detection_loss_box_reg: 0.0420 (0.0481)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0031)  time: 1.3932  data: 0.9113  max mem: 13299
# Epoch: [24]  [520/531]  eta: 0:00:13  lr: 0.010000  loss: 0.0845 (0.0814)  lesion-detection_performer-object_detection_loss_classifier: 0.0235 (0.0269)  lesion-detection_performer-object_detection_loss_box_reg: 0.0501 (0.0487)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0031)  time: 1.3869  data: 0.9183  max mem: 13299
# Epoch: [24]  [530/531]  eta: 0:00:01  lr: 0.010000  loss: 0.0906 (0.0814)  lesion-detection_performer-object_detection_loss_classifier: 0.0288 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0589 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0031)  time: 1.3313  data: 0.8778  max mem: 13299
# Epoch: [24] Total time: 0:10:33 (1.1926 s / it)
# Averaged stats: lr: 0.010000  loss: 0.0906 (0.0814)  lesion-detection_performer-object_detection_loss_classifier: 0.0288 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0589 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0015 (0.0027)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.16s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.282
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.283
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.188
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.390
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.390
# Evaluation:  [  0/114]  eta: 0:03:31  loss: 0.1210 (0.1210)  lesion-detection_performer-object_detection_loss_classifier: 0.0627 (0.0627)  lesion-detection_performer-object_detection_loss_box_reg: 0.0483 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0086 (0.0086)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0014 (0.0014)  model_time: 1679121664.0000 (1679121727.4492)  evaluator_time: 0.0000 (0.0000)  time: 1.8534  data: 1.6795  max mem: 13299
# Evaluation:  [100/114]  eta: 0:00:21  loss: 0.2143 (0.2181)  lesion-detection_performer-object_detection_loss_classifier: 0.1164 (0.1068)  lesion-detection_performer-object_detection_loss_box_reg: 0.0571 (0.0612)  lesion-detection_performer-object_detection_loss_objectness: 0.0311 (0.0455)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0047)  model_time: 1679121920.0000 (1679121803.8302)  evaluator_time: 0.0000 (0.0000)  time: 1.4615  data: 1.3497  max mem: 13299
# Evaluation:  [113/114]  eta: 0:00:01  loss: 0.2131 (0.2195)  lesion-detection_performer-object_detection_loss_classifier: 0.1143 (0.1081)  lesion-detection_performer-object_detection_loss_box_reg: 0.0549 (0.0609)  lesion-detection_performer-object_detection_loss_objectness: 0.0352 (0.0458)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0047)  model_time: 1679121920.0000 (1679121813.4920)  evaluator_time: 0.0000 (0.0000)  time: 1.4529  data: 1.3455  max mem: 13299
# Evaluation: Total time: 0:02:51 (1.5006 s / it)
# Averaged stats: loss: 0.2131 (0.2195)  lesion-detection_performer-object_detection_loss_classifier: 0.1143 (0.1081)  lesion-detection_performer-object_detection_loss_box_reg: 0.0549 (0.0609)  lesion-detection_performer-object_detection_loss_objectness: 0.0352 (0.0458)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0047)  model_time: 1679121920.0000 (1679121813.4920)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.150
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.150
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.194
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.363
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.363
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.363
# Evaluation:  [  0/114]  eta: 0:02:34  loss: 0.3232 (0.3232)  lesion-detection_performer-object_detection_loss_classifier: 0.2085 (0.2085)  lesion-detection_performer-object_detection_loss_box_reg: 0.0667 (0.0667)  lesion-detection_performer-object_detection_loss_objectness: 0.0429 (0.0429)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0051 (0.0051)  model_time: 1679121920.0000 (1679121898.1579)  evaluator_time: 0.0000 (0.0000)  time: 1.3525  data: 1.2540  max mem: 13299
# Evaluation:  [100/114]  eta: 0:00:19  loss: 0.1617 (0.2062)  lesion-detection_performer-object_detection_loss_classifier: 0.0872 (0.1032)  lesion-detection_performer-object_detection_loss_box_reg: 0.0466 (0.0548)  lesion-detection_performer-object_detection_loss_objectness: 0.0252 (0.0439)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0037 (0.0043)  model_time: 1679122048.0000 (1679121967.6350)  evaluator_time: 0.0000 (0.0000)  time: 1.4207  data: 1.3110  max mem: 13299
# Evaluation:  [113/114]  eta: 0:00:01  loss: 0.1617 (0.2074)  lesion-detection_performer-object_detection_loss_classifier: 0.0898 (0.1035)  lesion-detection_performer-object_detection_loss_box_reg: 0.0407 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0285 (0.0439)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0043)  model_time: 1679122048.0000 (1679121976.6598)  evaluator_time: 0.0000 (0.0000)  time: 1.4195  data: 1.3090  max mem: 13299
# Evaluation: Total time: 0:02:38 (1.3929 s / it)
# Averaged stats: loss: 0.1617 (0.2074)  lesion-detection_performer-object_detection_loss_classifier: 0.0898 (0.1035)  lesion-detection_performer-object_detection_loss_box_reg: 0.0407 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0285 (0.0439)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0043)  model_time: 1679122048.0000 (1679121976.6598)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.154
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.154
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.195
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.370
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.370
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.370
# ====================| EarlyStop | Epoch [24] Done | It has took [403.68] min, Avg time: [1009.21] sec/epoch | Estimate time for [50] epochs: [841.01] min | Epoch took [963] sec |====================
# ====================| Training Done, start testing! | [24] Epochs Training time: [24221] seconds, Avg time / Epoch: [1009.2083333333334] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_2117_test_lesion-detection_ap_0_2190_epoch8_03-18-2023 12-29-20_lesion_dsetection_with_fixation_efficientnet_b5]====================
# Evaluation:  [  0/114]  eta: 0:03:25  loss: 0.1633 (0.1633)  lesion-detection_performer-object_detection_loss_classifier: 0.0728 (0.0728)  lesion-detection_performer-object_detection_loss_box_reg: 0.0722 (0.0722)  lesion-detection_performer-object_detection_loss_objectness: 0.0166 (0.0166)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0016)  model_time: 1679122048.0000 (1679122057.4315)  evaluator_time: 0.0000 (0.0000)  time: 1.8066  data: 1.6675  max mem: 13299
# Evaluation:  [100/114]  eta: 0:00:19  loss: 0.2073 (0.2105)  lesion-detection_performer-object_detection_loss_classifier: 0.1088 (0.1059)  lesion-detection_performer-object_detection_loss_box_reg: 0.0580 (0.0569)  lesion-detection_performer-object_detection_loss_objectness: 0.0361 (0.0432)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0037 (0.0044)  model_time: 1679122176.0000 (1679122128.4251)  evaluator_time: 0.0000 (0.0000)  time: 1.3725  data: 1.2631  max mem: 13299
# Evaluation:  [113/114]  eta: 0:00:01  loss: 0.1922 (0.2066)  lesion-detection_performer-object_detection_loss_classifier: 0.0978 (0.1034)  lesion-detection_performer-object_detection_loss_box_reg: 0.0400 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0248 (0.0433)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0027 (0.0043)  model_time: 1679122176.0000 (1679122137.4607)  evaluator_time: 0.0000 (0.0000)  time: 1.3589  data: 1.2521  max mem: 13299
# Evaluation: Total time: 0:02:39 (1.4024 s / it)
# Averaged stats: loss: 0.1922 (0.2066)  lesion-detection_performer-object_detection_loss_classifier: 0.0978 (0.1034)  lesion-detection_performer-object_detection_loss_box_reg: 0.0400 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0248 (0.0433)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0027 (0.0043)  model_time: 1679122176.0000 (1679122137.4607)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.152
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.152
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.193
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.368
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.368
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.368
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1499_test_lesion-detection_ap_0_1515_epoch24_03-18-2023 16-50-15_lesion_dsetection_with_fixation_efficientnet_b5]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_efficientnet_b5]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_efficientnet_b5', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b5', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=4, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==============================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2117_test_lesion-detection_ap_0_2190_epoch8_03-18-2023 12-29-20_lesion_dsetection_with_fixation_efficientnet_b5]
# The final model has been saved to: [val_lesion-detection_ap_0_1499_test_lesion-detection_ap_0_1515_epoch24_03-18-2023 16-50-15_lesion_dsetection_with_fixation_efficientnet_b5]
#
# ==============================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
