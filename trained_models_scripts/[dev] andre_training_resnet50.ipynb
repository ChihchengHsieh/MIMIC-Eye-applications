# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 10,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}

vgg16_args = {
    "backbone": "vgg16",
    "using_fpn": False,
}

regnet_y_8gf_args = {
    "backbone": "regnet_y_8gf",
    "using_fpn": False,
}


convnext_base_args = {
    "backbone": "convnext_base",
    "using_fpn": False,
}

resnet50_args = {
    "backbone": "resnet50",
    "using_fpn": False,
}

# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_resnet50",
        **lesion_detection_best_args,
        **resnet50_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    ModelSetup(
        name="lesion_dsetection_baseline_resnet50",
        **lesion_detection_best_args,
        **resnet50_args,
        **small_model_args,
        **common_args,
        **without_fix_args,
    ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        # use Average Precision (Performance value) instead of loss in lr_scheduler.
        # val_loss = train_info.val_losses[-1]["loss"]
        val_performance_value = train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_performance_value)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resizeda
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [25] Done | It has took [192.80] min, Avg time: [462.72] sec/epoch | Estimate time for [50] epochs: [385.60] min | Epoch took [483] sec | Patience [10] |====================
# ====================Training model: [lesion_dsetection_baseline_resnet50]====================
# ========================================For Training [lesion_dsetection_baseline_resnet50]========================================
# ModelSetup(name='lesion_dsetection_baseline_resnet50', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='resnet50', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2130_test_lesion-detection_ap_0_2008_epoch15_03-22-2023 23-55-13_lesion_dsetection_baseline_resnet50]
# The final model has been saved to: [val_lesion-detection_ap_0_2130_test_lesion-detection_ap_0_2008_epoch15_03-22-2023 23-55-13_lesion_dsetection_baseline_resnet50]
#
# ==================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4225
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4219
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.2342
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.1858
# backbone weights fix status: False
# Epoch: [26]  [  0/266]  eta: 0:06:04  lr: 0.010000  loss: 0.0747 (0.0747)  lesion-detection_performer-object_detection_loss_classifier: 0.0287 (0.0287)  lesion-detection_performer-object_detection_loss_box_reg: 0.0419 (0.0419)  lesion-detection_performer-object_detection_loss_objectness: 0.0022 (0.0022)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0018)  time: 1.3717  data: 0.9572  max mem: 7687
# Epoch: [26]  [ 10/266]  eta: 0:04:51  lr: 0.010000  loss: 0.1051 (0.1243)  lesion-detection_performer-object_detection_loss_classifier: 0.0486 (0.0531)  lesion-detection_performer-object_detection_loss_box_reg: 0.0528 (0.0636)  lesion-detection_performer-object_detection_loss_objectness: 0.0036 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0027)  time: 1.1387  data: 0.9151  max mem: 7687
# Epoch: [26]  [ 20/266]  eta: 0:04:30  lr: 0.010000  loss: 0.1099 (0.1164)  lesion-detection_performer-object_detection_loss_classifier: 0.0463 (0.0493)  lesion-detection_performer-object_detection_loss_box_reg: 0.0589 (0.0603)  lesion-detection_performer-object_detection_loss_objectness: 0.0036 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.0874  data: 0.8916  max mem: 7687
# Epoch: [26]  [ 30/266]  eta: 0:04:17  lr: 0.010000  loss: 0.1078 (0.1121)  lesion-detection_performer-object_detection_loss_classifier: 0.0439 (0.0466)  lesion-detection_performer-object_detection_loss_box_reg: 0.0578 (0.0589)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0042)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0023)  time: 1.0629  data: 0.8758  max mem: 7687
# Epoch: [26]  [ 40/266]  eta: 0:04:04  lr: 0.010000  loss: 0.1022 (0.1127)  lesion-detection_performer-object_detection_loss_classifier: 0.0441 (0.0477)  lesion-detection_performer-object_detection_loss_box_reg: 0.0536 (0.0585)  lesion-detection_performer-object_detection_loss_objectness: 0.0029 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0023)  time: 1.0636  data: 0.8735  max mem: 7687
# Epoch: [26]  [ 50/266]  eta: 0:03:53  lr: 0.010000  loss: 0.1233 (0.1167)  lesion-detection_performer-object_detection_loss_classifier: 0.0491 (0.0494)  lesion-detection_performer-object_detection_loss_box_reg: 0.0666 (0.0603)  lesion-detection_performer-object_detection_loss_objectness: 0.0041 (0.0047)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0023)  time: 1.0669  data: 0.8733  max mem: 7687
# Epoch: [26]  [ 60/266]  eta: 0:03:41  lr: 0.010000  loss: 0.1242 (0.1177)  lesion-detection_performer-object_detection_loss_classifier: 0.0496 (0.0498)  lesion-detection_performer-object_detection_loss_box_reg: 0.0666 (0.0608)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0048)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 1.0650  data: 0.8751  max mem: 7687
# Epoch: [26]  [ 70/266]  eta: 0:03:30  lr: 0.010000  loss: 0.1038 (0.1152)  lesion-detection_performer-object_detection_loss_classifier: 0.0451 (0.0486)  lesion-detection_performer-object_detection_loss_box_reg: 0.0477 (0.0596)  lesion-detection_performer-object_detection_loss_objectness: 0.0052 (0.0048)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.0579  data: 0.8662  max mem: 7687
# Epoch: [26]  [ 80/266]  eta: 0:03:19  lr: 0.010000  loss: 0.0734 (0.1105)  lesion-detection_performer-object_detection_loss_classifier: 0.0320 (0.0466)  lesion-detection_performer-object_detection_loss_box_reg: 0.0432 (0.0571)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0047)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0021)  time: 1.0657  data: 0.8719  max mem: 7687
# Epoch: [26]  [ 90/266]  eta: 0:03:10  lr: 0.010000  loss: 0.0743 (0.1092)  lesion-detection_performer-object_detection_loss_classifier: 0.0318 (0.0459)  lesion-detection_performer-object_detection_loss_box_reg: 0.0431 (0.0566)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0021)  time: 1.0982  data: 0.9027  max mem: 7687
# Epoch: [26]  [100/266]  eta: 0:02:58  lr: 0.010000  loss: 0.0776 (0.1068)  lesion-detection_performer-object_detection_loss_classifier: 0.0361 (0.0453)  lesion-detection_performer-object_detection_loss_box_reg: 0.0408 (0.0550)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0021)  time: 1.0919  data: 0.8972  max mem: 7687
# Epoch: [26]  [110/266]  eta: 0:02:47  lr: 0.010000  loss: 0.0774 (0.1046)  lesion-detection_performer-object_detection_loss_classifier: 0.0305 (0.0441)  lesion-detection_performer-object_detection_loss_box_reg: 0.0391 (0.0541)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0043)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0021)  time: 1.0463  data: 0.8624  max mem: 7687
# Epoch: [26]  [120/266]  eta: 0:02:37  lr: 0.010000  loss: 0.0962 (0.1059)  lesion-detection_performer-object_detection_loss_classifier: 0.0417 (0.0446)  lesion-detection_performer-object_detection_loss_box_reg: 0.0525 (0.0549)  lesion-detection_performer-object_detection_loss_objectness: 0.0039 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0021)  time: 1.0726  data: 0.8835  max mem: 7687
# Epoch: [26]  [130/266]  eta: 0:02:26  lr: 0.010000  loss: 0.1103 (0.1064)  lesion-detection_performer-object_detection_loss_classifier: 0.0523 (0.0450)  lesion-detection_performer-object_detection_loss_box_reg: 0.0594 (0.0548)  lesion-detection_performer-object_detection_loss_objectness: 0.0056 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0021)  time: 1.1022  data: 0.9047  max mem: 7687
# Epoch: [26]  [140/266]  eta: 0:02:15  lr: 0.010000  loss: 0.0904 (0.1063)  lesion-detection_performer-object_detection_loss_classifier: 0.0413 (0.0451)  lesion-detection_performer-object_detection_loss_box_reg: 0.0460 (0.0545)  lesion-detection_performer-object_detection_loss_objectness: 0.0056 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 1.0546  data: 0.8681  max mem: 7687
# Epoch: [26]  [150/266]  eta: 0:02:04  lr: 0.010000  loss: 0.0927 (0.1065)  lesion-detection_performer-object_detection_loss_classifier: 0.0435 (0.0452)  lesion-detection_performer-object_detection_loss_box_reg: 0.0475 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0033 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 1.0216  data: 0.8402  max mem: 7687
# Epoch: [26]  [160/266]  eta: 0:01:53  lr: 0.010000  loss: 0.1062 (0.1065)  lesion-detection_performer-object_detection_loss_classifier: 0.0435 (0.0450)  lesion-detection_performer-object_detection_loss_box_reg: 0.0553 (0.0549)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 1.0504  data: 0.8614  max mem: 7687
# Epoch: [26]  [170/266]  eta: 0:01:42  lr: 0.010000  loss: 0.1062 (0.1077)  lesion-detection_performer-object_detection_loss_classifier: 0.0459 (0.0457)  lesion-detection_performer-object_detection_loss_box_reg: 0.0551 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.0656  data: 0.8827  max mem: 7687
# Epoch: [26]  [180/266]  eta: 0:01:31  lr: 0.010000  loss: 0.1207 (0.1086)  lesion-detection_performer-object_detection_loss_classifier: 0.0496 (0.0461)  lesion-detection_performer-object_detection_loss_box_reg: 0.0673 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0046)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0022)  time: 1.0563  data: 0.8726  max mem: 7687
# Epoch: [26]  [190/266]  eta: 0:01:21  lr: 0.010000  loss: 0.1129 (0.1080)  lesion-detection_performer-object_detection_loss_classifier: 0.0461 (0.0460)  lesion-detection_performer-object_detection_loss_box_reg: 0.0552 (0.0551)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0047)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0022)  time: 1.0547  data: 0.8660  max mem: 7687
# Epoch: [26]  [200/266]  eta: 0:01:10  lr: 0.010000  loss: 0.1000 (0.1085)  lesion-detection_performer-object_detection_loss_classifier: 0.0432 (0.0463)  lesion-detection_performer-object_detection_loss_box_reg: 0.0525 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0047)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.0516  data: 0.8639  max mem: 7687
# Epoch: [26]  [210/266]  eta: 0:00:59  lr: 0.010000  loss: 0.1022 (0.1087)  lesion-detection_performer-object_detection_loss_classifier: 0.0434 (0.0464)  lesion-detection_performer-object_detection_loss_box_reg: 0.0513 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0048 (0.0048)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0022)  time: 1.0478  data: 0.8665  max mem: 7687
# Epoch: [26]  [220/266]  eta: 0:00:49  lr: 0.010000  loss: 0.1022 (0.1085)  lesion-detection_performer-object_detection_loss_classifier: 0.0460 (0.0464)  lesion-detection_performer-object_detection_loss_box_reg: 0.0513 (0.0551)  lesion-detection_performer-object_detection_loss_objectness: 0.0047 (0.0048)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0022)  time: 1.0554  data: 0.8817  max mem: 7687
# Epoch: [26]  [230/266]  eta: 0:00:38  lr: 0.010000  loss: 0.0997 (0.1088)  lesion-detection_performer-object_detection_loss_classifier: 0.0460 (0.0467)  lesion-detection_performer-object_detection_loss_box_reg: 0.0480 (0.0551)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 1.0506  data: 0.8716  max mem: 7687
# Epoch: [26]  [240/266]  eta: 0:00:27  lr: 0.010000  loss: 0.0944 (0.1089)  lesion-detection_performer-object_detection_loss_classifier: 0.0411 (0.0467)  lesion-detection_performer-object_detection_loss_box_reg: 0.0465 (0.0552)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 1.0692  data: 0.8844  max mem: 7687
# Epoch: [26]  [250/266]  eta: 0:00:17  lr: 0.010000  loss: 0.0944 (0.1088)  lesion-detection_performer-object_detection_loss_classifier: 0.0400 (0.0466)  lesion-detection_performer-object_detection_loss_box_reg: 0.0495 (0.0551)  lesion-detection_performer-object_detection_loss_objectness: 0.0041 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 1.0902  data: 0.9052  max mem: 7687
# Epoch: [26]  [260/266]  eta: 0:00:06  lr: 0.010000  loss: 0.1077 (0.1095)  lesion-detection_performer-object_detection_loss_classifier: 0.0400 (0.0470)  lesion-detection_performer-object_detection_loss_box_reg: 0.0599 (0.0554)  lesion-detection_performer-object_detection_loss_objectness: 0.0041 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.0829  data: 0.8955  max mem: 7687
# Epoch: [26]  [265/266]  eta: 0:00:01  lr: 0.010000  loss: 0.1138 (0.1095)  lesion-detection_performer-object_detection_loss_classifier: 0.0502 (0.0470)  lesion-detection_performer-object_detection_loss_box_reg: 0.0599 (0.0554)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0022)  time: 1.0302  data: 0.8499  max mem: 7687
# Epoch: [26] Total time: 0:04:43 (1.0652 s / it)
# Averaged stats: lr: 0.010000  loss: 0.1138 (0.1095)  lesion-detection_performer-object_detection_loss_classifier: 0.0502 (0.0470)  lesion-detection_performer-object_detection_loss_box_reg: 0.0599 (0.0554)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0049)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0022)
# Accumulating evaluation results...
# DONE (t=0.17s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.288
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.230
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.480
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.480
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.480
# Evaluation:  [ 0/57]  eta: 0:01:35  loss: 0.2873 (0.2873)  lesion-detection_performer-object_detection_loss_classifier: 0.1566 (0.1566)  lesion-detection_performer-object_detection_loss_box_reg: 0.0772 (0.0772)  lesion-detection_performer-object_detection_loss_objectness: 0.0497 (0.0497)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0038)  model_time: 1679498496.0000 (1679498554.7760)  evaluator_time: 0.0000 (0.0000)  time: 1.6758  data: 1.5581  max mem: 7687
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2140 (0.2173)  lesion-detection_performer-object_detection_loss_classifier: 0.0998 (0.1138)  lesion-detection_performer-object_detection_loss_box_reg: 0.0726 (0.0690)  lesion-detection_performer-object_detection_loss_objectness: 0.0346 (0.0308)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0042 (0.0037)  model_time: 1679498624.0000 (1679498604.6562)  evaluator_time: 0.0000 (0.0000)  time: 1.7602  data: 1.5856  max mem: 7687
# Evaluation: Total time: 0:01:41 (1.7776 s / it)
# Averaged stats: loss: 0.2140 (0.2173)  lesion-detection_performer-object_detection_loss_classifier: 0.0998 (0.1138)  lesion-detection_performer-object_detection_loss_box_reg: 0.0726 (0.0690)  lesion-detection_performer-object_detection_loss_objectness: 0.0346 (0.0308)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0042 (0.0037)  model_time: 1679498624.0000 (1679498604.6562)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.173
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.174
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.237
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.489
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.489
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.489
# Evaluation:  [ 0/57]  eta: 0:01:34  loss: 0.1073 (0.1073)  lesion-detection_performer-object_detection_loss_classifier: 0.0680 (0.0680)  lesion-detection_performer-object_detection_loss_box_reg: 0.0202 (0.0202)  lesion-detection_performer-object_detection_loss_objectness: 0.0175 (0.0175)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0016)  model_time: 1679498624.0000 (1679498656.0273)  evaluator_time: 0.0000 (0.0000)  time: 1.6504  data: 1.3923  max mem: 7687
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.1780 (0.2051)  lesion-detection_performer-object_detection_loss_classifier: 0.0901 (0.1078)  lesion-detection_performer-object_detection_loss_box_reg: 0.0562 (0.0658)  lesion-detection_performer-object_detection_loss_objectness: 0.0287 (0.0282)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0034)  model_time: 1679498752.0000 (1679498705.3977)  evaluator_time: 0.0000 (0.0000)  time: 1.7059  data: 1.5329  max mem: 7687
# Evaluation: Total time: 0:01:38 (1.7365 s / it)
# Averaged stats: loss: 0.1780 (0.2051)  lesion-detection_performer-object_detection_loss_classifier: 0.0901 (0.1078)  lesion-detection_performer-object_detection_loss_box_reg: 0.0562 (0.0658)  lesion-detection_performer-object_detection_loss_objectness: 0.0287 (0.0282)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0034)  model_time: 1679498752.0000 (1679498705.3977)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.166
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.230
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.508
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.508
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.508
# ====================| EarlyStop | Epoch [26] Done | It has took [200.90] min, Avg time: [463.62] sec/epoch | Estimate time for [50] epochs: [386.35] min | Epoch took [484] sec |====================
# ====================| Training Done, start testing! | [26] Epochs Training time: [12054] seconds, Avg time / Epoch: [463.61538461538464] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_2130_test_lesion-detection_ap_0_2008_epoch15_03-22-2023 23-55-13_lesion_dsetection_baseline_resnet50]====================
# Evaluation:  [ 0/57]  eta: 0:01:27  loss: 0.3905 (0.3905)  lesion-detection_performer-object_detection_loss_classifier: 0.1924 (0.1924)  lesion-detection_performer-object_detection_loss_box_reg: 0.1196 (0.1196)  lesion-detection_performer-object_detection_loss_objectness: 0.0700 (0.0700)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0085 (0.0085)  model_time: 1679498752.0000 (1679498755.1306)  evaluator_time: 0.0000 (0.0000)  time: 1.5297  data: 1.4282  max mem: 7687
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.1789 (0.2040)  lesion-detection_performer-object_detection_loss_classifier: 0.0938 (0.1076)  lesion-detection_performer-object_detection_loss_box_reg: 0.0640 (0.0658)  lesion-detection_performer-object_detection_loss_objectness: 0.0240 (0.0273)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0034)  model_time: 1679498880.0000 (1679498803.8166)  evaluator_time: 0.0000 (0.0000)  time: 1.7251  data: 1.5423  max mem: 7687
# Evaluation: Total time: 0:01:38 (1.7311 s / it)
# Averaged stats: loss: 0.1789 (0.2040)  lesion-detection_performer-object_detection_loss_classifier: 0.0938 (0.1076)  lesion-detection_performer-object_detection_loss_box_reg: 0.0640 (0.0658)  lesion-detection_performer-object_detection_loss_objectness: 0.0240 (0.0273)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0030 (0.0034)  model_time: 1679498880.0000 (1679498803.8166)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.165
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.166
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.228
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.509
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.509
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.509
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1731_test_lesion-detection_ap_0_1654_epoch26_03-23-2023 01-27-32_lesion_dsetection_baseline_resnet50]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_resnet50]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_resnet50', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='resnet50', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =======================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2234_test_lesion-detection_ap_0_2142_epoch12_03-22-2023 19-34-11_lesion_dsetection_with_fixation_resnet50]
# The final model has been saved to: [val_lesion-detection_ap_0_1893_test_lesion-detection_ap_0_1887_epoch23_03-22-2023 22-04-57_lesion_dsetection_with_fixation_resnet50]
#
# =======================================================================================================================================
# ========================================For Training [lesion_dsetection_baseline_resnet50]========================================
# ModelSetup(name='lesion_dsetection_baseline_resnet50', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='resnet50', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2130_test_lesion-detection_ap_0_2008_epoch15_03-22-2023 23-55-13_lesion_dsetection_baseline_resnet50]
# The final model has been saved to: [val_lesion-detection_ap_0_1731_test_lesion-detection_ap_0_1654_epoch26_03-23-2023 01-27-32_lesion_dsetection_baseline_resnet50]
#
# ==================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
