# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 20,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}
# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_efficientnet_b0",
        **lesion_detection_best_args,
        **efficientnet_b0_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    ModelSetup(
        name="lesion_dsetection_baseline_efficientnet_b0",
        **lesion_detection_best_args,
        **efficientnet_b0_args,
        **small_model_args,
        **common_args,
        **without_fix_args,
    ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        val_loss = train_info.val_losses[-1]["loss"]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_loss)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resized
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [36] Done | It has took [224.30] min, Avg time: [373.83] sec/epoch | Estimate time for [50] epochs: [311.53] min | Epoch took [315] sec | Patience [20] |====================
# ====================Training model: [lesion_dsetection_baseline_efficientnet_b0]====================
# ========================================For Training [lesion_dsetection_baseline_efficientnet_b0]========================================
# ModelSetup(name='lesion_dsetection_baseline_efficientnet_b0', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b0', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =========================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1934_test_lesion-detection_ap_0_1858_epoch10_03-18-2023 23-50-47_lesion_dsetection_baseline_efficientnet_b0]
# The final model has been saved to: [val_lesion-detection_ap_0_1934_test_lesion-detection_ap_0_1858_epoch10_03-18-2023 23-50-47_lesion_dsetection_baseline_efficientnet_b0]
#
# =========================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.3937
# [lesion-detection_performer-object_detection_loss_classifier]: 0.3678
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.2126
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.1633
# backbone weights fix status: False
# Epoch: [37]  [  0/266]  eta: 0:04:27  lr: 0.010000  loss: 0.0428 (0.0428)  lesion-detection_performer-object_detection_loss_classifier: 0.0150 (0.0150)  lesion-detection_performer-object_detection_loss_box_reg: 0.0253 (0.0253)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0016)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0066  data: 0.6246  max mem: 7470
# Epoch: [37]  [ 10/266]  eta: 0:03:06  lr: 0.010000  loss: 0.0767 (0.0927)  lesion-detection_performer-object_detection_loss_classifier: 0.0278 (0.0361)  lesion-detection_performer-object_detection_loss_box_reg: 0.0450 (0.0517)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0014 (0.0018)  time: 0.7284  data: 0.5926  max mem: 7470
# Epoch: [37]  [ 20/266]  eta: 0:02:56  lr: 0.010000  loss: 0.0730 (0.0826)  lesion-detection_performer-object_detection_loss_classifier: 0.0278 (0.0318)  lesion-detection_performer-object_detection_loss_box_reg: 0.0383 (0.0462)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0014 (0.0016)  time: 0.7034  data: 0.5934  max mem: 7470
# Epoch: [37]  [ 30/266]  eta: 0:02:50  lr: 0.010000  loss: 0.0823 (0.0870)  lesion-detection_performer-object_detection_loss_classifier: 0.0313 (0.0341)  lesion-detection_performer-object_detection_loss_box_reg: 0.0390 (0.0481)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0014 (0.0017)  time: 0.7172  data: 0.5985  max mem: 7470
# Epoch: [37]  [ 40/266]  eta: 0:02:42  lr: 0.010000  loss: 0.0842 (0.0880)  lesion-detection_performer-object_detection_loss_classifier: 0.0307 (0.0341)  lesion-detection_performer-object_detection_loss_box_reg: 0.0491 (0.0491)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.7160  data: 0.5932  max mem: 7470
# Epoch: [37]  [ 50/266]  eta: 0:02:34  lr: 0.010000  loss: 0.0790 (0.0861)  lesion-detection_performer-object_detection_loss_classifier: 0.0275 (0.0330)  lesion-detection_performer-object_detection_loss_box_reg: 0.0466 (0.0485)  lesion-detection_performer-object_detection_loss_objectness: 0.0016 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.7036  data: 0.5889  max mem: 7470
# Epoch: [37]  [ 60/266]  eta: 0:02:27  lr: 0.010000  loss: 0.0853 (0.0905)  lesion-detection_performer-object_detection_loss_classifier: 0.0323 (0.0348)  lesion-detection_performer-object_detection_loss_box_reg: 0.0480 (0.0509)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0019)  time: 0.7069  data: 0.5934  max mem: 7470
# Epoch: [37]  [ 70/266]  eta: 0:02:19  lr: 0.010000  loss: 0.0879 (0.0893)  lesion-detection_performer-object_detection_loss_classifier: 0.0341 (0.0345)  lesion-detection_performer-object_detection_loss_box_reg: 0.0480 (0.0501)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.7086  data: 0.5932  max mem: 7470
# Epoch: [37]  [ 80/266]  eta: 0:02:13  lr: 0.010000  loss: 0.0699 (0.0870)  lesion-detection_performer-object_detection_loss_classifier: 0.0264 (0.0340)  lesion-detection_performer-object_detection_loss_box_reg: 0.0401 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0019)  time: 0.7260  data: 0.6032  max mem: 7470
# Epoch: [37]  [ 90/266]  eta: 0:02:06  lr: 0.010000  loss: 0.0756 (0.0881)  lesion-detection_performer-object_detection_loss_classifier: 0.0282 (0.0342)  lesion-detection_performer-object_detection_loss_box_reg: 0.0438 (0.0491)  lesion-detection_performer-object_detection_loss_objectness: 0.0018 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.7439  data: 0.6185  max mem: 7470
# Epoch: [37]  [100/266]  eta: 0:01:59  lr: 0.010000  loss: 0.0881 (0.0880)  lesion-detection_performer-object_detection_loss_classifier: 0.0325 (0.0342)  lesion-detection_performer-object_detection_loss_box_reg: 0.0500 (0.0490)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0019)  time: 0.7337  data: 0.6200  max mem: 7470
# Epoch: [37]  [110/266]  eta: 0:01:52  lr: 0.010000  loss: 0.0860 (0.0872)  lesion-detection_performer-object_detection_loss_classifier: 0.0325 (0.0339)  lesion-detection_performer-object_detection_loss_box_reg: 0.0486 (0.0486)  lesion-detection_performer-object_detection_loss_objectness: 0.0020 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0015 (0.0019)  time: 0.7290  data: 0.6164  max mem: 7470
# Epoch: [37]  [120/266]  eta: 0:01:45  lr: 0.010000  loss: 0.0823 (0.0863)  lesion-detection_performer-object_detection_loss_classifier: 0.0291 (0.0332)  lesion-detection_performer-object_detection_loss_box_reg: 0.0457 (0.0483)  lesion-detection_performer-object_detection_loss_objectness: 0.0024 (0.0028)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.7223  data: 0.6043  max mem: 7470
# Epoch: [37]  [130/266]  eta: 0:01:38  lr: 0.010000  loss: 0.0872 (0.0870)  lesion-detection_performer-object_detection_loss_classifier: 0.0302 (0.0334)  lesion-detection_performer-object_detection_loss_box_reg: 0.0534 (0.0488)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0029)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.7193  data: 0.6055  max mem: 7470
# Epoch: [37]  [140/266]  eta: 0:01:30  lr: 0.010000  loss: 0.0943 (0.0882)  lesion-detection_performer-object_detection_loss_classifier: 0.0351 (0.0341)  lesion-detection_performer-object_detection_loss_box_reg: 0.0573 (0.0492)  lesion-detection_performer-object_detection_loss_objectness: 0.0039 (0.0030)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0019)  time: 0.7275  data: 0.6168  max mem: 7470
# Epoch: [37]  [150/266]  eta: 0:01:23  lr: 0.010000  loss: 0.0849 (0.0885)  lesion-detection_performer-object_detection_loss_classifier: 0.0319 (0.0342)  lesion-detection_performer-object_detection_loss_box_reg: 0.0485 (0.0493)  lesion-detection_performer-object_detection_loss_objectness: 0.0039 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0015 (0.0019)  time: 0.7101  data: 0.6029  max mem: 7470
# Epoch: [37]  [160/266]  eta: 0:01:16  lr: 0.010000  loss: 0.0809 (0.0891)  lesion-detection_performer-object_detection_loss_classifier: 0.0308 (0.0344)  lesion-detection_performer-object_detection_loss_box_reg: 0.0485 (0.0498)  lesion-detection_performer-object_detection_loss_objectness: 0.0034 (0.0031)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0014 (0.0019)  time: 0.7069  data: 0.6006  max mem: 7470
# Epoch: [37]  [170/266]  eta: 0:01:09  lr: 0.010000  loss: 0.0960 (0.0899)  lesion-detection_performer-object_detection_loss_classifier: 0.0331 (0.0347)  lesion-detection_performer-object_detection_loss_box_reg: 0.0513 (0.0502)  lesion-detection_performer-object_detection_loss_objectness: 0.0031 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.7251  data: 0.6127  max mem: 7470
# Epoch: [37]  [180/266]  eta: 0:01:01  lr: 0.010000  loss: 0.0929 (0.0903)  lesion-detection_performer-object_detection_loss_classifier: 0.0339 (0.0348)  lesion-detection_performer-object_detection_loss_box_reg: 0.0555 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0026 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.7242  data: 0.6082  max mem: 7470
# Epoch: [37]  [190/266]  eta: 0:00:54  lr: 0.010000  loss: 0.0901 (0.0911)  lesion-detection_performer-object_detection_loss_classifier: 0.0406 (0.0353)  lesion-detection_performer-object_detection_loss_box_reg: 0.0555 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.7272  data: 0.6064  max mem: 7470
# Epoch: [37]  [200/266]  eta: 0:00:47  lr: 0.010000  loss: 0.0804 (0.0902)  lesion-detection_performer-object_detection_loss_classifier: 0.0339 (0.0349)  lesion-detection_performer-object_detection_loss_box_reg: 0.0456 (0.0502)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.7306  data: 0.6040  max mem: 7470
# Epoch: [37]  [210/266]  eta: 0:00:40  lr: 0.010000  loss: 0.0673 (0.0898)  lesion-detection_performer-object_detection_loss_classifier: 0.0249 (0.0347)  lesion-detection_performer-object_detection_loss_box_reg: 0.0408 (0.0499)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.7195  data: 0.5997  max mem: 7470
# Epoch: [37]  [220/266]  eta: 0:00:33  lr: 0.010000  loss: 0.0761 (0.0904)  lesion-detection_performer-object_detection_loss_classifier: 0.0309 (0.0350)  lesion-detection_performer-object_detection_loss_box_reg: 0.0478 (0.0503)  lesion-detection_performer-object_detection_loss_objectness: 0.0020 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0019)  time: 0.7057  data: 0.5918  max mem: 7470
# Epoch: [37]  [230/266]  eta: 0:00:25  lr: 0.010000  loss: 0.0868 (0.0903)  lesion-detection_performer-object_detection_loss_classifier: 0.0334 (0.0350)  lesion-detection_performer-object_detection_loss_box_reg: 0.0500 (0.0502)  lesion-detection_performer-object_detection_loss_objectness: 0.0022 (0.0032)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.7072  data: 0.5935  max mem: 7470
# Epoch: [37]  [240/266]  eta: 0:00:18  lr: 0.010000  loss: 0.0878 (0.0910)  lesion-detection_performer-object_detection_loss_classifier: 0.0339 (0.0353)  lesion-detection_performer-object_detection_loss_box_reg: 0.0484 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0033)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.7163  data: 0.6014  max mem: 7470
# Epoch: [37]  [250/266]  eta: 0:00:11  lr: 0.010000  loss: 0.0898 (0.0911)  lesion-detection_performer-object_detection_loss_classifier: 0.0364 (0.0353)  lesion-detection_performer-object_detection_loss_box_reg: 0.0482 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0039 (0.0033)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.7232  data: 0.6041  max mem: 7470
# Epoch: [37]  [260/266]  eta: 0:00:04  lr: 0.010000  loss: 0.0898 (0.0915)  lesion-detection_performer-object_detection_loss_classifier: 0.0357 (0.0356)  lesion-detection_performer-object_detection_loss_box_reg: 0.0482 (0.0507)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0033)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0019)  time: 0.7235  data: 0.6066  max mem: 7470
# Epoch: [37]  [265/266]  eta: 0:00:00  lr: 0.010000  loss: 0.0903 (0.0918)  lesion-detection_performer-object_detection_loss_classifier: 0.0361 (0.0357)  lesion-detection_performer-object_detection_loss_box_reg: 0.0482 (0.0509)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0033)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0019)  time: 0.6861  data: 0.5753  max mem: 7470
# Epoch: [37] Total time: 0:03:10 (0.7173 s / it)
# Averaged stats: lr: 0.010000  loss: 0.0903 (0.0918)  lesion-detection_performer-object_detection_loss_classifier: 0.0361 (0.0357)  lesion-detection_performer-object_detection_loss_box_reg: 0.0482 (0.0509)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0033)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.282
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.283
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.198
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.411
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.411
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.411
# Evaluation:  [ 0/57]  eta: 0:01:03  loss: 0.1732 (0.1732)  lesion-detection_performer-object_detection_loss_classifier: 0.0881 (0.0881)  lesion-detection_performer-object_detection_loss_box_reg: 0.0393 (0.0393)  lesion-detection_performer-object_detection_loss_objectness: 0.0429 (0.0429)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0028)  model_time: 1679156736.0000 (1679156692.7981)  evaluator_time: 0.0000 (0.0000)  time: 1.1059  data: 1.0579  max mem: 7470
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2483 (0.2470)  lesion-detection_performer-object_detection_loss_classifier: 0.1239 (0.1317)  lesion-detection_performer-object_detection_loss_box_reg: 0.0694 (0.0707)  lesion-detection_performer-object_detection_loss_objectness: 0.0373 (0.0407)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0039)  model_time: 1679156736.0000 (1679156723.7227)  evaluator_time: 0.0000 (0.0000)  time: 1.1148  data: 0.9809  max mem: 7470
# Evaluation: Total time: 0:01:03 (1.1117 s / it)
# Averaged stats: loss: 0.2483 (0.2470)  lesion-detection_performer-object_detection_loss_classifier: 0.1239 (0.1317)  lesion-detection_performer-object_detection_loss_box_reg: 0.0694 (0.0707)  lesion-detection_performer-object_detection_loss_objectness: 0.0373 (0.0407)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0039 (0.0039)  model_time: 1679156736.0000 (1679156723.7227)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.157
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.157
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.215
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.419
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.419
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.419
# Evaluation:  [ 0/57]  eta: 0:01:06  loss: 0.3535 (0.3535)  lesion-detection_performer-object_detection_loss_classifier: 0.1702 (0.1702)  lesion-detection_performer-object_detection_loss_box_reg: 0.1455 (0.1455)  lesion-detection_performer-object_detection_loss_objectness: 0.0332 (0.0332)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0046 (0.0046)  model_time: 1679156736.0000 (1679156756.2020)  evaluator_time: 0.0000 (0.0000)  time: 1.1687  data: 1.0406  max mem: 7470
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2004 (0.2379)  lesion-detection_performer-object_detection_loss_classifier: 0.1138 (0.1301)  lesion-detection_performer-object_detection_loss_box_reg: 0.0539 (0.0689)  lesion-detection_performer-object_detection_loss_objectness: 0.0306 (0.0353)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0036)  model_time: 1679156864.0000 (1679156787.0663)  evaluator_time: 0.0000 (0.0000)  time: 1.0763  data: 0.9679  max mem: 7470
# Evaluation: Total time: 0:01:02 (1.0946 s / it)
# Averaged stats: loss: 0.2004 (0.2379)  lesion-detection_performer-object_detection_loss_classifier: 0.1138 (0.1301)  lesion-detection_performer-object_detection_loss_box_reg: 0.0539 (0.0689)  lesion-detection_performer-object_detection_loss_objectness: 0.0306 (0.0353)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0034 (0.0036)  model_time: 1679156864.0000 (1679156787.0663)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.141
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.141
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.205
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.419
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.419
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.419
# ====================| EarlyStop | Epoch [37] Done | It has took [229.60] min, Avg time: [372.32] sec/epoch | Estimate time for [50] epochs: [310.27] min | Epoch took [316] sec |====================
# ====================| Training Done, start testing! | [37] Epochs Training time: [13776] seconds, Avg time / Epoch: [372.3243243243243] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_1934_test_lesion-detection_ap_0_1858_epoch10_03-18-2023 23-50-47_lesion_dsetection_baseline_efficientnet_b0]====================
# Evaluation:  [ 0/57]  eta: 0:00:56  loss: 0.1771 (0.1771)  lesion-detection_performer-object_detection_loss_classifier: 0.0969 (0.0969)  lesion-detection_performer-object_detection_loss_box_reg: 0.0554 (0.0554)  lesion-detection_performer-object_detection_loss_objectness: 0.0214 (0.0214)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0033 (0.0033)  model_time: 1679156864.0000 (1679156818.4696)  evaluator_time: 0.0000 (0.0000)  time: 0.9838  data: 0.8623  max mem: 7470
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2527 (0.2375)  lesion-detection_performer-object_detection_loss_classifier: 0.1425 (0.1302)  lesion-detection_performer-object_detection_loss_box_reg: 0.0794 (0.0688)  lesion-detection_performer-object_detection_loss_objectness: 0.0308 (0.0349)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0036)  model_time: 1679156864.0000 (1679156849.2301)  evaluator_time: 0.0000 (0.0000)  time: 1.0946  data: 0.9715  max mem: 7470
# Evaluation: Total time: 0:01:02 (1.0911 s / it)
# Averaged stats: loss: 0.2527 (0.2375)  lesion-detection_performer-object_detection_loss_classifier: 0.1425 (0.1302)  lesion-detection_performer-object_detection_loss_box_reg: 0.0794 (0.0688)  lesion-detection_performer-object_detection_loss_objectness: 0.0308 (0.0349)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0036)  model_time: 1679156864.0000 (1679156849.2301)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.138
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.138
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.202
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.414
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.414
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.414
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1571_test_lesion-detection_ap_0_1381_epoch37_03-19-2023 02-27-59_lesion_dsetection_baseline_efficientnet_b0]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_efficientnet_b0]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_efficientnet_b0', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b0', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==============================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2191_test_lesion-detection_ap_0_2162_epoch10_03-18-2023 19-38-11_lesion_dsetection_with_fixation_efficientnet_b0]
# The final model has been saved to: [val_lesion-detection_ap_0_1766_test_lesion-detection_ap_0_1758_epoch24_03-18-2023 22-37-19_lesion_dsetection_with_fixation_efficientnet_b0]
#
# ==============================================================================================================================================
# ========================================For Training [lesion_dsetection_baseline_efficientnet_b0]========================================
# ModelSetup(name='lesion_dsetection_baseline_efficientnet_b0', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='efficientnet_b0', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=20, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# =========================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1934_test_lesion-detection_ap_0_1858_epoch10_03-18-2023 23-50-47_lesion_dsetection_baseline_efficientnet_b0]
# The final model has been saved to: [val_lesion-detection_ap_0_1571_test_lesion-detection_ap_0_1381_epoch37_03-19-2023 02-27-59_lesion_dsetection_baseline_efficientnet_b0]
#
# =========================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
