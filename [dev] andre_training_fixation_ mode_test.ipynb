# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 10,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

silent_report_args = {
    "fiaxtions_mode_input": "silent"
}

full_report_args = {
    "fiaxtions_mode_input": "normal"
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}

vgg16_args = {
    "backbone": "vgg16",
    "using_fpn": False,
}

regnet_y_8gf_args = {
    "backbone": "regnet_y_8gf",
    "using_fpn": False,
}

convnext_base_args = {
    "backbone": "convnext_base",
    "using_fpn": False,
}

resnet50_args = {
    "backbone": "resnet50",
    "using_fpn": False,
}

# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_convnext_base_silent_report",
        **lesion_detection_best_args,
        **convnext_base_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
        # **silent_report_args, # see if disabling this will get more time.
    ),
    ModelSetup(
        name="lesion_dsetection_with_fixation_convnext_base_full_report",
        **lesion_detection_best_args,
        **convnext_base_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
        **full_report_args,
    ),

    # ModelSetup(
    #     name="lesion_dsetection_baseline_resnet50",
    #     **lesion_detection_best_args,
    #     **resnet50_args,
    #     **small_model_args,
    #     **common_args,
    #     **without_fix_args,
    # ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()

    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        # use Average Precision (Performance value) instead of loss in lr_scheduler.
        # val_loss = train_info.val_losses[-1]["loss"]
        val_performance_value = train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_performance_value)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resizeda
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [32] Done | It has took [464.42] min, Avg time: [870.78] sec/epoch | Estimate time for [50] epochs: [725.65] min | Epoch took [829] sec | Patience [10] |====================
# ====================Training model: [lesion_dsetection_with_fixation_convnext_base_full_report]====================
# ========================================For Training [lesion_dsetection_with_fixation_convnext_base_full_report]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_convnext_base_full_report', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='convnext_base', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='normal', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ========================================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2602_test_lesion-detection_ap_0_2499_epoch22_03-24-2023 04-42-21_lesion_dsetection_with_fixation_convnext_base_full_report]
# The final model has been saved to: [val_lesion-detection_ap_0_2602_test_lesion-detection_ap_0_2499_epoch22_03-24-2023 04-42-21_lesion_dsetection_with_fixation_convnext_base_full_report]
#
# ========================================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4280
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4040
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.2235
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.1899
# backbone weights fix status: False
# backbone weights fix status: False
# Epoch: [33]  [  0/266]  eta: 0:10:46  lr: 0.010000  loss: 0.1350 (0.1350)  lesion-detection_performer-object_detection_loss_classifier: 0.0500 (0.0500)  lesion-detection_performer-object_detection_loss_box_reg: 0.0785 (0.0785)  lesion-detection_performer-object_detection_loss_objectness: 0.0047 (0.0047)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0018)  time: 2.4297  data: 1.4229  max mem: 20797
# Epoch: [33]  [ 10/266]  eta: 0:09:32  lr: 0.010000  loss: 0.0956 (0.0948)  lesion-detection_performer-object_detection_loss_classifier: 0.0396 (0.0380)  lesion-detection_performer-object_detection_loss_box_reg: 0.0498 (0.0505)  lesion-detection_performer-object_detection_loss_objectness: 0.0047 (0.0044)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 2.2375  data: 1.3547  max mem: 20797
# Epoch: [33]  [ 20/266]  eta: 0:09:07  lr: 0.010000  loss: 0.0956 (0.0939)  lesion-detection_performer-object_detection_loss_classifier: 0.0396 (0.0392)  lesion-detection_performer-object_detection_loss_box_reg: 0.0475 (0.0481)  lesion-detection_performer-object_detection_loss_objectness: 0.0045 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 2.2165  data: 1.3454  max mem: 20797
# Epoch: [33]  [ 30/266]  eta: 0:08:40  lr: 0.010000  loss: 0.0972 (0.0962)  lesion-detection_performer-object_detection_loss_classifier: 0.0397 (0.0403)  lesion-detection_performer-object_detection_loss_box_reg: 0.0467 (0.0485)  lesion-detection_performer-object_detection_loss_objectness: 0.0048 (0.0051)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 2.1857  data: 1.3143  max mem: 20797
# Epoch: [33]  [ 40/266]  eta: 0:08:17  lr: 0.010000  loss: 0.0791 (0.0984)  lesion-detection_performer-object_detection_loss_classifier: 0.0354 (0.0409)  lesion-detection_performer-object_detection_loss_box_reg: 0.0452 (0.0502)  lesion-detection_performer-object_detection_loss_objectness: 0.0055 (0.0051)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0022)  time: 2.1708  data: 1.2996  max mem: 20797
# Epoch: [33]  [ 50/266]  eta: 0:07:55  lr: 0.010000  loss: 0.0921 (0.1015)  lesion-detection_performer-object_detection_loss_classifier: 0.0383 (0.0420)  lesion-detection_performer-object_detection_loss_box_reg: 0.0493 (0.0519)  lesion-detection_performer-object_detection_loss_objectness: 0.0054 (0.0052)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0023)  time: 2.1934  data: 1.3207  max mem: 20797
# Epoch: [33]  [ 60/266]  eta: 0:07:32  lr: 0.010000  loss: 0.0921 (0.0995)  lesion-detection_performer-object_detection_loss_classifier: 0.0383 (0.0413)  lesion-detection_performer-object_detection_loss_box_reg: 0.0452 (0.0506)  lesion-detection_performer-object_detection_loss_objectness: 0.0055 (0.0053)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0024)  time: 2.1876  data: 1.3156  max mem: 20797
# Epoch: [33]  [ 70/266]  eta: 0:07:09  lr: 0.010000  loss: 0.0903 (0.0989)  lesion-detection_performer-object_detection_loss_classifier: 0.0357 (0.0412)  lesion-detection_performer-object_detection_loss_box_reg: 0.0432 (0.0501)  lesion-detection_performer-object_detection_loss_objectness: 0.0046 (0.0053)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0024)  time: 2.1784  data: 1.3094  max mem: 20797
# Epoch: [33]  [ 80/266]  eta: 0:06:47  lr: 0.010000  loss: 0.0948 (0.1016)  lesion-detection_performer-object_detection_loss_classifier: 0.0430 (0.0425)  lesion-detection_performer-object_detection_loss_box_reg: 0.0487 (0.0513)  lesion-detection_performer-object_detection_loss_objectness: 0.0044 (0.0054)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0024)  time: 2.1850  data: 1.3130  max mem: 20797
# Epoch: [33]  [ 90/266]  eta: 0:06:25  lr: 0.010000  loss: 0.1036 (0.1039)  lesion-detection_performer-object_detection_loss_classifier: 0.0504 (0.0438)  lesion-detection_performer-object_detection_loss_box_reg: 0.0470 (0.0521)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0056)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0024)  time: 2.1895  data: 1.3140  max mem: 20797
# Epoch: [33]  [100/266]  eta: 0:06:03  lr: 0.010000  loss: 0.1271 (0.1069)  lesion-detection_performer-object_detection_loss_classifier: 0.0517 (0.0450)  lesion-detection_performer-object_detection_loss_box_reg: 0.0624 (0.0536)  lesion-detection_performer-object_detection_loss_objectness: 0.0066 (0.0058)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0025)  time: 2.1917  data: 1.3160  max mem: 20797
# Epoch: [33]  [110/266]  eta: 0:05:42  lr: 0.010000  loss: 0.1236 (0.1066)  lesion-detection_performer-object_detection_loss_classifier: 0.0514 (0.0451)  lesion-detection_performer-object_detection_loss_box_reg: 0.0624 (0.0533)  lesion-detection_performer-object_detection_loss_objectness: 0.0065 (0.0058)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0024)  time: 2.2092  data: 1.3291  max mem: 20797
# Epoch: [33]  [120/266]  eta: 0:05:21  lr: 0.010000  loss: 0.1096 (0.1071)  lesion-detection_performer-object_detection_loss_classifier: 0.0443 (0.0452)  lesion-detection_performer-object_detection_loss_box_reg: 0.0562 (0.0537)  lesion-detection_performer-object_detection_loss_objectness: 0.0059 (0.0057)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0024)  time: 2.2291  data: 1.3477  max mem: 20797
# Epoch: [33]  [130/266]  eta: 0:04:59  lr: 0.010000  loss: 0.1197 (0.1088)  lesion-detection_performer-object_detection_loss_classifier: 0.0489 (0.0460)  lesion-detection_performer-object_detection_loss_box_reg: 0.0608 (0.0545)  lesion-detection_performer-object_detection_loss_objectness: 0.0059 (0.0059)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0024)  time: 2.2170  data: 1.3368  max mem: 20797
# Epoch: [33]  [140/266]  eta: 0:04:37  lr: 0.010000  loss: 0.1248 (0.1108)  lesion-detection_performer-object_detection_loss_classifier: 0.0540 (0.0469)  lesion-detection_performer-object_detection_loss_box_reg: 0.0608 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0078 (0.0060)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0025)  time: 2.2131  data: 1.3332  max mem: 20797
# Epoch: [33]  [150/266]  eta: 0:04:14  lr: 0.010000  loss: 0.1176 (0.1105)  lesion-detection_performer-object_detection_loss_classifier: 0.0524 (0.0469)  lesion-detection_performer-object_detection_loss_box_reg: 0.0582 (0.0552)  lesion-detection_performer-object_detection_loss_objectness: 0.0061 (0.0059)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0025)  time: 2.1925  data: 1.3164  max mem: 20797
# Epoch: [33]  [160/266]  eta: 0:03:53  lr: 0.010000  loss: 0.1046 (0.1097)  lesion-detection_performer-object_detection_loss_classifier: 0.0461 (0.0467)  lesion-detection_performer-object_detection_loss_box_reg: 0.0504 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0043 (0.0059)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0024)  time: 2.1830  data: 1.3066  max mem: 20797
# Epoch: [33]  [170/266]  eta: 0:03:30  lr: 0.010000  loss: 0.1109 (0.1105)  lesion-detection_performer-object_detection_loss_classifier: 0.0522 (0.0472)  lesion-detection_performer-object_detection_loss_box_reg: 0.0522 (0.0550)  lesion-detection_performer-object_detection_loss_objectness: 0.0057 (0.0058)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0025)  time: 2.1929  data: 1.3154  max mem: 20797
# Epoch: [33]  [180/266]  eta: 0:03:08  lr: 0.010000  loss: 0.1123 (0.1109)  lesion-detection_performer-object_detection_loss_classifier: 0.0473 (0.0473)  lesion-detection_performer-object_detection_loss_box_reg: 0.0552 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0058 (0.0059)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0025)  time: 2.1723  data: 1.2979  max mem: 20797
# Epoch: [33]  [190/266]  eta: 0:02:47  lr: 0.010000  loss: 0.1217 (0.1117)  lesion-detection_performer-object_detection_loss_classifier: 0.0470 (0.0476)  lesion-detection_performer-object_detection_loss_box_reg: 0.0575 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0063 (0.0060)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0027 (0.0025)  time: 2.2011  data: 1.3235  max mem: 20797
# Epoch: [33]  [200/266]  eta: 0:02:25  lr: 0.010000  loss: 0.1229 (0.1124)  lesion-detection_performer-object_detection_loss_classifier: 0.0498 (0.0478)  lesion-detection_performer-object_detection_loss_box_reg: 0.0616 (0.0560)  lesion-detection_performer-object_detection_loss_objectness: 0.0071 (0.0061)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0027 (0.0025)  time: 2.2160  data: 1.3361  max mem: 20797
# Epoch: [33]  [210/266]  eta: 0:02:03  lr: 0.010000  loss: 0.1025 (0.1116)  lesion-detection_performer-object_detection_loss_classifier: 0.0420 (0.0475)  lesion-detection_performer-object_detection_loss_box_reg: 0.0523 (0.0555)  lesion-detection_performer-object_detection_loss_objectness: 0.0067 (0.0060)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0025)  time: 2.1907  data: 1.3126  max mem: 20797
# Epoch: [33]  [220/266]  eta: 0:01:41  lr: 0.010000  loss: 0.0974 (0.1133)  lesion-detection_performer-object_detection_loss_classifier: 0.0420 (0.0483)  lesion-detection_performer-object_detection_loss_box_reg: 0.0509 (0.0563)  lesion-detection_performer-object_detection_loss_objectness: 0.0046 (0.0062)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0025)  time: 2.1980  data: 1.3217  max mem: 20797
# Epoch: [33]  [230/266]  eta: 0:01:19  lr: 0.010000  loss: 0.1245 (0.1140)  lesion-detection_performer-object_detection_loss_classifier: 0.0554 (0.0487)  lesion-detection_performer-object_detection_loss_box_reg: 0.0550 (0.0564)  lesion-detection_performer-object_detection_loss_objectness: 0.0085 (0.0063)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0025)  time: 2.1905  data: 1.3173  max mem: 20797
# Epoch: [33]  [240/266]  eta: 0:00:57  lr: 0.010000  loss: 0.1023 (0.1129)  lesion-detection_performer-object_detection_loss_classifier: 0.0445 (0.0483)  lesion-detection_performer-object_detection_loss_box_reg: 0.0492 (0.0559)  lesion-detection_performer-object_detection_loss_objectness: 0.0049 (0.0062)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0025)  time: 2.1890  data: 1.3150  max mem: 20797
# Epoch: [33]  [250/266]  eta: 0:00:35  lr: 0.010000  loss: 0.1024 (0.1132)  lesion-detection_performer-object_detection_loss_classifier: 0.0439 (0.0484)  lesion-detection_performer-object_detection_loss_box_reg: 0.0516 (0.0561)  lesion-detection_performer-object_detection_loss_objectness: 0.0049 (0.0062)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0025)  time: 2.1983  data: 1.3244  max mem: 20797
# Epoch: [33]  [260/266]  eta: 0:00:13  lr: 0.010000  loss: 0.1164 (0.1128)  lesion-detection_performer-object_detection_loss_classifier: 0.0529 (0.0484)  lesion-detection_performer-object_detection_loss_box_reg: 0.0566 (0.0558)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0061)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0025)  time: 2.1879  data: 1.3137  max mem: 20797
# Epoch: [33]  [265/266]  eta: 0:00:02  lr: 0.010000  loss: 0.1164 (0.1126)  lesion-detection_performer-object_detection_loss_classifier: 0.0529 (0.0483)  lesion-detection_performer-object_detection_loss_box_reg: 0.0542 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0062)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0025)  time: 2.1072  data: 1.2636  max mem: 20797
# Epoch: [33] Total time: 0:09:42 (2.1905 s / it)
# Averaged stats: lr: 0.010000  loss: 0.1164 (0.1126)  lesion-detection_performer-object_detection_loss_classifier: 0.0529 (0.0483)  lesion-detection_performer-object_detection_loss_box_reg: 0.0542 (0.0556)  lesion-detection_performer-object_detection_loss_objectness: 0.0053 (0.0062)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.274
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.275
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.233
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.488
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.488
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.488
# Evaluation:  [ 0/57]  eta: 0:02:01  loss: 0.1444 (0.1444)  lesion-detection_performer-object_detection_loss_classifier: 0.0872 (0.0872)  lesion-detection_performer-object_detection_loss_box_reg: 0.0380 (0.0380)  lesion-detection_performer-object_detection_loss_objectness: 0.0174 (0.0174)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0018)  model_time: 1679605760.0000 (1679605813.2523)  evaluator_time: 0.0000 (0.0000)  time: 2.1249  data: 1.8487  max mem: 20797
# Evaluation:  [56/57]  eta: 0:00:02  loss: 0.2150 (0.2126)  lesion-detection_performer-object_detection_loss_classifier: 0.1149 (0.1085)  lesion-detection_performer-object_detection_loss_box_reg: 0.0736 (0.0706)  lesion-detection_performer-object_detection_loss_objectness: 0.0277 (0.0293)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0041)  model_time: 1679605888.0000 (1679605874.4466)  evaluator_time: 0.0000 (0.0000)  time: 2.2040  data: 1.9238  max mem: 20797
# Evaluation: Total time: 0:02:04 (2.1871 s / it)
# Averaged stats: loss: 0.2150 (0.2126)  lesion-detection_performer-object_detection_loss_classifier: 0.1149 (0.1085)  lesion-detection_performer-object_detection_loss_box_reg: 0.0736 (0.0706)  lesion-detection_performer-object_detection_loss_objectness: 0.0277 (0.0293)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0041)  model_time: 1679605888.0000 (1679605874.4466)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.199
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.199
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.220
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.462
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.462
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.462
# Evaluation:  [ 0/57]  eta: 0:02:09  loss: 0.3092 (0.3092)  lesion-detection_performer-object_detection_loss_classifier: 0.1409 (0.1409)  lesion-detection_performer-object_detection_loss_box_reg: 0.1370 (0.1370)  lesion-detection_performer-object_detection_loss_objectness: 0.0266 (0.0266)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0047 (0.0047)  model_time: 1679605888.0000 (1679605938.0747)  evaluator_time: 0.0000 (0.0000)  time: 2.2667  data: 1.9516  max mem: 20797
# Evaluation:  [56/57]  eta: 0:00:02  loss: 0.1595 (0.2064)  lesion-detection_performer-object_detection_loss_classifier: 0.0925 (0.1091)  lesion-detection_performer-object_detection_loss_box_reg: 0.0494 (0.0680)  lesion-detection_performer-object_detection_loss_objectness: 0.0194 (0.0254)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0039)  model_time: 1679606016.0000 (1679605998.5839)  evaluator_time: 0.0000 (0.0000)  time: 2.1294  data: 1.8655  max mem: 20797
# Evaluation: Total time: 0:02:02 (2.1566 s / it)
# Averaged stats: loss: 0.1595 (0.2064)  lesion-detection_performer-object_detection_loss_classifier: 0.0925 (0.1091)  lesion-detection_performer-object_detection_loss_box_reg: 0.0494 (0.0680)  lesion-detection_performer-object_detection_loss_objectness: 0.0194 (0.0254)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0031 (0.0039)  model_time: 1679606016.0000 (1679605998.5839)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.186
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.186
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.211
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.466
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.466
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.466
# ====================| EarlyStop | Epoch [33] Done | It has took [478.28] min, Avg time: [869.61] sec/epoch | Estimate time for [50] epochs: [724.67] min | Epoch took [830] sec |====================
# ====================| Training Done, start testing! | [33] Epochs Training time: [28697] seconds, Avg time / Epoch: [869.6060606060606] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_2602_test_lesion-detection_ap_0_2499_epoch22_03-24-2023 04-42-21_lesion_dsetection_with_fixation_convnext_base_full_report]====================
# Evaluation:  [ 0/57]  eta: 0:01:50  loss: 0.1148 (0.1148)  lesion-detection_performer-object_detection_loss_classifier: 0.0496 (0.0496)  lesion-detection_performer-object_detection_loss_box_reg: 0.0403 (0.0403)  lesion-detection_performer-object_detection_loss_objectness: 0.0203 (0.0203)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0045 (0.0045)  model_time: 1679606016.0000 (1679606060.7938)  evaluator_time: 0.0000 (0.0000)  time: 1.9464  data: 1.6834  max mem: 20797
# Evaluation:  [56/57]  eta: 0:00:02  loss: 0.2207 (0.2062)  lesion-detection_performer-object_detection_loss_classifier: 0.1132 (0.1087)  lesion-detection_performer-object_detection_loss_box_reg: 0.0598 (0.0679)  lesion-detection_performer-object_detection_loss_objectness: 0.0238 (0.0258)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0041 (0.0039)  model_time: 1679606144.0000 (1679606121.3862)  evaluator_time: 0.0000 (0.0000)  time: 2.1285  data: 1.8771  max mem: 20797
# Evaluation: Total time: 0:02:02 (2.1468 s / it)
# Averaged stats: loss: 0.2207 (0.2062)  lesion-detection_performer-object_detection_loss_classifier: 0.1132 (0.1087)  lesion-detection_performer-object_detection_loss_box_reg: 0.0598 (0.0679)  lesion-detection_performer-object_detection_loss_objectness: 0.0238 (0.0258)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0041 (0.0039)  model_time: 1679606144.0000 (1679606121.3862)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.187
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.187
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.208
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.467
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.467
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.467
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1988_test_lesion-detection_ap_0_1872_epoch33_03-24-2023 07-16-21_lesion_dsetection_with_fixation_convnext_base_full_report]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_convnext_base_silent_report]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_convnext_base_silent_report', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='convnext_base', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ==========================================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2472_test_lesion-detection_ap_0_2637_epoch15_03-23-2023 20-20-07_lesion_dsetection_with_fixation_convnext_base_silent_report]
# The final model has been saved to: [val_lesion-detection_ap_0_2277_test_lesion-detection_ap_0_2329_epoch26_03-23-2023 23-15-58_lesion_dsetection_with_fixation_convnext_base_silent_report]
#
# ==========================================================================================================================================================
# ========================================For Training [lesion_dsetection_with_fixation_convnext_base_full_report]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_convnext_base_full_report', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='convnext_base', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='normal', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ========================================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2602_test_lesion-detection_ap_0_2499_epoch22_03-24-2023 04-42-21_lesion_dsetection_with_fixation_convnext_base_full_report]
# The final model has been saved to: [val_lesion-detection_ap_0_1988_test_lesion-detection_ap_0_1872_epoch33_03-24-2023 07-16-21_lesion_dsetection_with_fixation_convnext_base_full_report]
#
# ========================================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
