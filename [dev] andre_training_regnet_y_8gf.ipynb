# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 10,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}

vgg16_args = {
    "backbone": "vgg16",
    "using_fpn": False,
}

regnet_y_8gf_args = {
    "backbone": "regnet_y_8gf",
    "using_fpn": False,
}

# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_regnet_y_8gf",
        **lesion_detection_best_args,
        **regnet_y_8gf_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    ModelSetup(
        name="lesion_dsetection_baseline_regnet_y_8gf",
        **lesion_detection_best_args,
        **regnet_y_8gf_args,
        **small_model_args,
        **common_args,
        **without_fix_args,
    ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        # use Average Precision (Performance value) instead of loss in lr_scheduler.
        # val_loss = train_info.val_losses[-1]["loss"]
        val_performance_value = train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_performance_value)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resized
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [23] Done | It has took [146.28] min, Avg time: [381.61] sec/epoch | Estimate time for [50] epochs: [318.01] min | Epoch took [350] sec | Patience [10] |====================
# ====================Training model: [lesion_dsetection_baseline_regnet_y_8gf]====================
# ========================================For Training [lesion_dsetection_baseline_regnet_y_8gf]========================================
# ModelSetup(name='lesion_dsetection_baseline_regnet_y_8gf', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='regnet_y_8gf', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ======================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1883_test_lesion-detection_ap_0_1658_epoch13_03-21-2023 15-22-32_lesion_dsetection_baseline_regnet_y_8gf]
# The final model has been saved to: [val_lesion-detection_ap_0_1883_test_lesion-detection_ap_0_1658_epoch13_03-21-2023 15-22-32_lesion_dsetection_baseline_regnet_y_8gf]
#
# ======================================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4207
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4053
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.2312
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.1865
# backbone weights fix status: False
# Epoch: [24]  [  0/266]  eta: 0:04:22  lr: 0.010000  loss: 0.1043 (0.1043)  lesion-detection_performer-object_detection_loss_classifier: 0.0345 (0.0345)  lesion-detection_performer-object_detection_loss_box_reg: 0.0625 (0.0625)  lesion-detection_performer-object_detection_loss_objectness: 0.0051 (0.0051)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0022)  time: 0.9874  data: 0.6413  max mem: 14844
# Epoch: [24]  [ 10/266]  eta: 0:03:42  lr: 0.010000  loss: 0.1043 (0.0982)  lesion-detection_performer-object_detection_loss_classifier: 0.0375 (0.0388)  lesion-detection_performer-object_detection_loss_box_reg: 0.0625 (0.0536)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0035)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0023)  time: 0.8683  data: 0.6423  max mem: 14844
# Epoch: [24]  [ 20/266]  eta: 0:03:28  lr: 0.010000  loss: 0.0838 (0.0932)  lesion-detection_performer-object_detection_loss_classifier: 0.0362 (0.0364)  lesion-detection_performer-object_detection_loss_box_reg: 0.0468 (0.0509)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0023)  time: 0.8405  data: 0.6291  max mem: 14844
# Epoch: [24]  [ 30/266]  eta: 0:03:18  lr: 0.010000  loss: 0.0964 (0.1003)  lesion-detection_performer-object_detection_loss_classifier: 0.0368 (0.0405)  lesion-detection_performer-object_detection_loss_box_reg: 0.0468 (0.0539)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 0.8290  data: 0.6166  max mem: 14844
# Epoch: [24]  [ 40/266]  eta: 0:03:12  lr: 0.010000  loss: 0.1055 (0.0984)  lesion-detection_performer-object_detection_loss_classifier: 0.0438 (0.0403)  lesion-detection_performer-object_detection_loss_box_reg: 0.0555 (0.0523)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 0.8543  data: 0.6363  max mem: 14844
# Epoch: [24]  [ 50/266]  eta: 0:03:04  lr: 0.010000  loss: 0.1036 (0.0981)  lesion-detection_performer-object_detection_loss_classifier: 0.0406 (0.0397)  lesion-detection_performer-object_detection_loss_box_reg: 0.0555 (0.0526)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 0.8746  data: 0.6567  max mem: 14844
# Epoch: [24]  [ 60/266]  eta: 0:02:57  lr: 0.010000  loss: 0.1038 (0.1030)  lesion-detection_performer-object_detection_loss_classifier: 0.0406 (0.0417)  lesion-detection_performer-object_detection_loss_box_reg: 0.0593 (0.0553)  lesion-detection_performer-object_detection_loss_objectness: 0.0037 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0023)  time: 0.8815  data: 0.6646  max mem: 14844
# Epoch: [24]  [ 70/266]  eta: 0:02:48  lr: 0.010000  loss: 0.1078 (0.1022)  lesion-detection_performer-object_detection_loss_classifier: 0.0428 (0.0416)  lesion-detection_performer-object_detection_loss_box_reg: 0.0575 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0037 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 0.8756  data: 0.6595  max mem: 14844
# Epoch: [24]  [ 80/266]  eta: 0:02:40  lr: 0.010000  loss: 0.0909 (0.1008)  lesion-detection_performer-object_detection_loss_classifier: 0.0338 (0.0405)  lesion-detection_performer-object_detection_loss_box_reg: 0.0510 (0.0546)  lesion-detection_performer-object_detection_loss_objectness: 0.0027 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 0.8713  data: 0.6573  max mem: 14844
# Epoch: [24]  [ 90/266]  eta: 0:02:32  lr: 0.010000  loss: 0.0957 (0.0998)  lesion-detection_performer-object_detection_loss_classifier: 0.0340 (0.0397)  lesion-detection_performer-object_detection_loss_box_reg: 0.0515 (0.0545)  lesion-detection_performer-object_detection_loss_objectness: 0.0023 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0021)  time: 0.8890  data: 0.6731  max mem: 14844
# Epoch: [24]  [100/266]  eta: 0:02:24  lr: 0.010000  loss: 0.0957 (0.1009)  lesion-detection_performer-object_detection_loss_classifier: 0.0370 (0.0400)  lesion-detection_performer-object_detection_loss_box_reg: 0.0563 (0.0552)  lesion-detection_performer-object_detection_loss_objectness: 0.0034 (0.0036)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0025 (0.0022)  time: 0.8947  data: 0.6766  max mem: 14844
# Epoch: [24]  [110/266]  eta: 0:02:14  lr: 0.010000  loss: 0.0918 (0.1005)  lesion-detection_performer-object_detection_loss_classifier: 0.0384 (0.0397)  lesion-detection_performer-object_detection_loss_box_reg: 0.0497 (0.0549)  lesion-detection_performer-object_detection_loss_objectness: 0.0033 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0021)  time: 0.8490  data: 0.6356  max mem: 14844
# Epoch: [24]  [120/266]  eta: 0:02:05  lr: 0.010000  loss: 0.0921 (0.1010)  lesion-detection_performer-object_detection_loss_classifier: 0.0384 (0.0403)  lesion-detection_performer-object_detection_loss_box_reg: 0.0497 (0.0549)  lesion-detection_performer-object_detection_loss_objectness: 0.0034 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 0.8275  data: 0.6197  max mem: 14844
# Epoch: [24]  [130/266]  eta: 0:01:56  lr: 0.010000  loss: 0.0954 (0.1010)  lesion-detection_performer-object_detection_loss_classifier: 0.0393 (0.0402)  lesion-detection_performer-object_detection_loss_box_reg: 0.0512 (0.0550)  lesion-detection_performer-object_detection_loss_objectness: 0.0038 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0022)  time: 0.8390  data: 0.6255  max mem: 14844
# Epoch: [24]  [140/266]  eta: 0:01:48  lr: 0.010000  loss: 0.0917 (0.1003)  lesion-detection_performer-object_detection_loss_classifier: 0.0336 (0.0399)  lesion-detection_performer-object_detection_loss_box_reg: 0.0472 (0.0545)  lesion-detection_performer-object_detection_loss_objectness: 0.0034 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 0.8316  data: 0.6170  max mem: 14844
# Epoch: [24]  [150/266]  eta: 0:01:39  lr: 0.010000  loss: 0.0897 (0.1008)  lesion-detection_performer-object_detection_loss_classifier: 0.0340 (0.0401)  lesion-detection_performer-object_detection_loss_box_reg: 0.0422 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0028 (0.0037)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0022)  time: 0.8420  data: 0.6311  max mem: 14844
# Epoch: [24]  [160/266]  eta: 0:01:30  lr: 0.010000  loss: 0.0884 (0.1009)  lesion-detection_performer-object_detection_loss_classifier: 0.0348 (0.0402)  lesion-detection_performer-object_detection_loss_box_reg: 0.0494 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0038)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 0.8528  data: 0.6403  max mem: 14844
# Epoch: [24]  [170/266]  eta: 0:01:22  lr: 0.010000  loss: 0.0809 (0.0994)  lesion-detection_performer-object_detection_loss_classifier: 0.0308 (0.0396)  lesion-detection_performer-object_detection_loss_box_reg: 0.0431 (0.0538)  lesion-detection_performer-object_detection_loss_objectness: 0.0037 (0.0038)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0022)  time: 0.8396  data: 0.6298  max mem: 14844
# Epoch: [24]  [180/266]  eta: 0:01:13  lr: 0.010000  loss: 0.0809 (0.0995)  lesion-detection_performer-object_detection_loss_classifier: 0.0308 (0.0397)  lesion-detection_performer-object_detection_loss_box_reg: 0.0431 (0.0538)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0039)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0022)  time: 0.8297  data: 0.6187  max mem: 14844
# Epoch: [24]  [190/266]  eta: 0:01:05  lr: 0.010000  loss: 0.0855 (0.0986)  lesion-detection_performer-object_detection_loss_classifier: 0.0356 (0.0394)  lesion-detection_performer-object_detection_loss_box_reg: 0.0494 (0.0532)  lesion-detection_performer-object_detection_loss_objectness: 0.0030 (0.0038)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0021)  time: 0.8533  data: 0.6355  max mem: 14844
# Epoch: [24]  [200/266]  eta: 0:00:56  lr: 0.010000  loss: 0.0804 (0.0983)  lesion-detection_performer-object_detection_loss_classifier: 0.0370 (0.0393)  lesion-detection_performer-object_detection_loss_box_reg: 0.0410 (0.0530)  lesion-detection_performer-object_detection_loss_objectness: 0.0021 (0.0038)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0016 (0.0021)  time: 0.8492  data: 0.6336  max mem: 14844
# Epoch: [24]  [210/266]  eta: 0:00:47  lr: 0.010000  loss: 0.1026 (0.0996)  lesion-detection_performer-object_detection_loss_classifier: 0.0389 (0.0398)  lesion-detection_performer-object_detection_loss_box_reg: 0.0593 (0.0538)  lesion-detection_performer-object_detection_loss_objectness: 0.0039 (0.0039)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 0.8302  data: 0.6197  max mem: 14844
# Epoch: [24]  [220/266]  eta: 0:00:39  lr: 0.010000  loss: 0.1129 (0.1001)  lesion-detection_performer-object_detection_loss_classifier: 0.0394 (0.0400)  lesion-detection_performer-object_detection_loss_box_reg: 0.0593 (0.0539)  lesion-detection_performer-object_detection_loss_objectness: 0.0045 (0.0040)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0022)  time: 0.8207  data: 0.6110  max mem: 14844
# Epoch: [24]  [230/266]  eta: 0:00:30  lr: 0.010000  loss: 0.0994 (0.1001)  lesion-detection_performer-object_detection_loss_classifier: 0.0320 (0.0400)  lesion-detection_performer-object_detection_loss_box_reg: 0.0500 (0.0539)  lesion-detection_performer-object_detection_loss_objectness: 0.0036 (0.0040)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0022)  time: 0.8290  data: 0.6192  max mem: 14844
# Epoch: [24]  [240/266]  eta: 0:00:22  lr: 0.010000  loss: 0.1001 (0.1004)  lesion-detection_performer-object_detection_loss_classifier: 0.0389 (0.0401)  lesion-detection_performer-object_detection_loss_box_reg: 0.0567 (0.0542)  lesion-detection_performer-object_detection_loss_objectness: 0.0033 (0.0040)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 0.8343  data: 0.6243  max mem: 14844
# Epoch: [24]  [250/266]  eta: 0:00:13  lr: 0.010000  loss: 0.1055 (0.1005)  lesion-detection_performer-object_detection_loss_classifier: 0.0373 (0.0400)  lesion-detection_performer-object_detection_loss_box_reg: 0.0622 (0.0543)  lesion-detection_performer-object_detection_loss_objectness: 0.0025 (0.0040)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0022)  time: 0.8119  data: 0.6021  max mem: 14844
# Epoch: [24]  [260/266]  eta: 0:00:05  lr: 0.010000  loss: 0.0862 (0.1010)  lesion-detection_performer-object_detection_loss_classifier: 0.0353 (0.0402)  lesion-detection_performer-object_detection_loss_box_reg: 0.0557 (0.0546)  lesion-detection_performer-object_detection_loss_objectness: 0.0032 (0.0040)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 0.8087  data: 0.5990  max mem: 14844
# Epoch: [24]  [265/266]  eta: 0:00:00  lr: 0.010000  loss: 0.1055 (0.1010)  lesion-detection_performer-object_detection_loss_classifier: 0.0330 (0.0401)  lesion-detection_performer-object_detection_loss_box_reg: 0.0620 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0042 (0.0041)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)  time: 0.7860  data: 0.5831  max mem: 14844
# Epoch: [24] Total time: 0:03:44 (0.8439 s / it)
# Averaged stats: lr: 0.010000  loss: 0.1055 (0.1010)  lesion-detection_performer-object_detection_loss_classifier: 0.0330 (0.0401)  lesion-detection_performer-object_detection_loss_box_reg: 0.0620 (0.0547)  lesion-detection_performer-object_detection_loss_objectness: 0.0042 (0.0041)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0022)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.267
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.269
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.203
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.428
# Evaluation:  [ 0/57]  eta: 0:01:03  loss: 0.2130 (0.2130)  lesion-detection_performer-object_detection_loss_classifier: 0.0906 (0.0906)  lesion-detection_performer-object_detection_loss_box_reg: 0.0583 (0.0583)  lesion-detection_performer-object_detection_loss_objectness: 0.0613 (0.0613)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0028)  model_time: 1679379968.0000 (1679379986.4670)  evaluator_time: 0.0000 (0.0000)  time: 1.1196  data: 1.0411  max mem: 14844
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2293 (0.2411)  lesion-detection_performer-object_detection_loss_classifier: 0.1219 (0.1215)  lesion-detection_performer-object_detection_loss_box_reg: 0.0672 (0.0715)  lesion-detection_performer-object_detection_loss_objectness: 0.0400 (0.0434)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0047)  model_time: 1679380096.0000 (1679380017.7745)  evaluator_time: 0.0000 (0.0000)  time: 1.1333  data: 1.0232  max mem: 14844
# Evaluation: Total time: 0:01:04 (1.1279 s / it)
# Averaged stats: loss: 0.2293 (0.2411)  lesion-detection_performer-object_detection_loss_classifier: 0.1219 (0.1215)  lesion-detection_performer-object_detection_loss_box_reg: 0.0672 (0.0715)  lesion-detection_performer-object_detection_loss_objectness: 0.0400 (0.0434)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0047)  model_time: 1679380096.0000 (1679380017.7745)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.133
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.134
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.208
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.413
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.413
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.413
# Evaluation:  [ 0/57]  eta: 0:01:10  loss: 0.1812 (0.1812)  lesion-detection_performer-object_detection_loss_classifier: 0.0936 (0.0936)  lesion-detection_performer-object_detection_loss_box_reg: 0.0686 (0.0686)  lesion-detection_performer-object_detection_loss_objectness: 0.0166 (0.0166)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0024)  model_time: 1679380096.0000 (1679380050.8664)  evaluator_time: 0.0000 (0.0000)  time: 1.2429  data: 1.0983  max mem: 14844
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2255 (0.2324)  lesion-detection_performer-object_detection_loss_classifier: 0.1141 (0.1203)  lesion-detection_performer-object_detection_loss_box_reg: 0.0675 (0.0696)  lesion-detection_performer-object_detection_loss_objectness: 0.0364 (0.0382)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0042)  model_time: 1679380096.0000 (1679380082.0045)  evaluator_time: 0.0000 (0.0000)  time: 1.1485  data: 1.0420  max mem: 14844
# Evaluation: Total time: 0:01:03 (1.1194 s / it)
# Averaged stats: loss: 0.2255 (0.2324)  lesion-detection_performer-object_detection_loss_classifier: 0.1141 (0.1203)  lesion-detection_performer-object_detection_loss_box_reg: 0.0675 (0.0696)  lesion-detection_performer-object_detection_loss_objectness: 0.0364 (0.0382)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0042)  model_time: 1679380096.0000 (1679380082.0045)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.128
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.129
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.194
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.407
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.407
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.407
# ====================| EarlyStop | Epoch [24] Done | It has took [152.18] min, Avg time: [380.46] sec/epoch | Estimate time for [50] epochs: [317.05] min | Epoch took [352] sec |====================
# ====================| Training Done, start testing! | [24] Epochs Training time: [9131] seconds, Avg time / Epoch: [380.4583333333333] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_1883_test_lesion-detection_ap_0_1658_epoch13_03-21-2023 15-22-32_lesion_dsetection_baseline_regnet_y_8gf]====================
# Evaluation:  [ 0/57]  eta: 0:01:06  loss: 0.3020 (0.3020)  lesion-detection_performer-object_detection_loss_classifier: 0.1484 (0.1484)  lesion-detection_performer-object_detection_loss_box_reg: 0.0952 (0.0952)  lesion-detection_performer-object_detection_loss_objectness: 0.0531 (0.0531)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0052 (0.0052)  model_time: 1679380096.0000 (1679380114.6613)  evaluator_time: 0.0000 (0.0000)  time: 1.1636  data: 1.0345  max mem: 14844
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2448 (0.2309)  lesion-detection_performer-object_detection_loss_classifier: 0.1059 (0.1200)  lesion-detection_performer-object_detection_loss_box_reg: 0.0708 (0.0696)  lesion-detection_performer-object_detection_loss_objectness: 0.0292 (0.0372)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0043 (0.0042)  model_time: 1679380224.0000 (1679380146.0299)  evaluator_time: 0.0000 (0.0000)  time: 1.1488  data: 1.0324  max mem: 14844
# Evaluation: Total time: 0:01:04 (1.1255 s / it)
# Averaged stats: loss: 0.2448 (0.2309)  lesion-detection_performer-object_detection_loss_classifier: 0.1059 (0.1200)  lesion-detection_performer-object_detection_loss_box_reg: 0.0708 (0.0696)  lesion-detection_performer-object_detection_loss_objectness: 0.0292 (0.0372)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0043 (0.0042)  model_time: 1679380224.0000 (1679380146.0299)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.130
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.131
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.195
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.407
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.407
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.407
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1330_test_lesion-detection_ap_0_1298_epoch24_03-21-2023 16-29-37_lesion_dsetection_baseline_regnet_y_8gf]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_regnet_y_8gf]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_regnet_y_8gf', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='regnet_y_8gf', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ===========================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2267_test_lesion-detection_ap_0_2029_epoch12_03-21-2023 11-28-48_lesion_dsetection_with_fixation_regnet_y_8gf]
# The final model has been saved to: [val_lesion-detection_ap_0_1799_test_lesion-detection_ap_0_1777_epoch23_03-21-2023 13-56-19_lesion_dsetection_with_fixation_regnet_y_8gf]
#
# ===========================================================================================================================================
# ========================================For Training [lesion_dsetection_baseline_regnet_y_8gf]========================================
# ModelSetup(name='lesion_dsetection_baseline_regnet_y_8gf', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='regnet_y_8gf', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ======================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_1883_test_lesion-detection_ap_0_1658_epoch13_03-21-2023 15-22-32_lesion_dsetection_baseline_regnet_y_8gf]
# The final model has been saved to: [val_lesion-detection_ap_0_1330_test_lesion-detection_ap_0_1298_epoch24_03-21-2023 16-29-37_lesion_dsetection_baseline_regnet_y_8gf]
#
# ======================================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
