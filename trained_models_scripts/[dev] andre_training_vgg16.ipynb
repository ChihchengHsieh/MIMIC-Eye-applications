# %%
import pandas as pd
import numpy as np
import torch
import utils.print as print_f
import os

from utils.engine import evaluate, get_iou_types
from utils.plot import plot_losses, plot_performance
from data.strs import TaskStrs, SourceStrs, FusionStrs

from models.utils import get_model_size_in_MB
from models.build import create_model_from_setup
from models.setup import ModelSetup
from models.train import TrainingInfo
from utils.save import check_best, end_train, get_data_from_metric_logger
from data.load import get_datasets, get_dataloaders
from IPython.display import clear_output
from utils.eval import get_ap_ar, get_ap_ar_for_train_val, get_performance
from utils.train import get_optimiser, get_lr_scheduler, print_params_setup, get_coco_eval_params, get_dynamic_loss
from utils.init import reproducibility, clean_memory_get_device
from data.paths import MIMIC_EYE_PATH
# from datetime import datetime
# from models.dynamic_loss import DynamicWeightedLoss
from utils.engine import train_one_epoch, evaluate
from torch import optim
from models.setup import ModelSetup
from data.paths import MIMIC_EYE_PATH
# from data.load import seed_worker, get_dataloader_g

## Suppress the assignement warning from pandas.r
pd.options.mode.chained_assignment = None  # default='warn'

## Supress user warning
import warnings
warnings.filterwarnings("ignore")

from models.components.task_performers import ObjectDetectionPerformer
from data.constants import DEFAULT_MIMIC_CLINICAL_NUM_COLS, DEFAULT_MIMIC_CLINICAL_CAT_COLS
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:256"
# 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:512'

# %%
device = clean_memory_get_device()
reproducibility()
# Out:
# This notebook will running on device: [CUDA]

# %%
if torch.cuda.is_available():
    print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# fix backbones
common_args = {
    "decoder_channels": [128, 64, 32, 16, 8],
    "optimiser": "sgd",
    "lr": 1e-2,  # 1e-5,  # 1e-3 is a trainable value.
    "batch_size": 8,
    "sgb_momentum": 0.9,
    "weight_decay": 1e-5,  # 1e-5
    # "pretrained": True,
    "image_size": 512,
    "record_training_performance": False,
    "warmup_epochs": 0,
    "lr_scheduler": "ReduceLROnPlateau",  # ReduceLROnPlateau, MultiStepLR
    "reduceLROnPlateau_factor": 0.5,
    "reduceLROnPlateau_patience": 10,
    "reduceLROnPlateau_full_stop": True, # set to false to continue run.
    "multiStepLR_milestones": [20, 40, 60, 80, 100],  # list(range(1,100)),
    "multiStepLR_gamma": 0.5,
    "use_mask": False,
    "gt_in_train_till": 0,
    "box_head_dropout_rate": 0,
    "model_warmup_epochs": 0,  # stop fixing the weights in the backbone.
    "loss_warmup_epochs": 0,  # should be larger than model warm up.
    "measure_test": True,
    "use_dynamic_weight": True,
}

chexpert_best_args = {
    "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
    "performance_standard_metric": "auc",
}

lesion_detection_best_args = {
    "performance_standard_task": TaskStrs.LESION_DETECTION,
    "performance_standard_metric": "ap",
}

with_fix_args = {
    "sources": [SourceStrs.XRAYS, SourceStrs.FIXATIONS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

without_fix_args = {
    "sources": [SourceStrs.XRAYS],
    # "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
    "tasks": [
        TaskStrs.LESION_DETECTION,
        # TaskStrs.FIXATION_GENERATION,
        # TaskStrs.CHEXPERT_CLASSIFICATION,
        # TaskStrs.NEGBIO_CLASSIFICATION,
    ],
    "fusor": FusionStrs.ElEMENTWISE_SUM,
}

small_model_args = {
    "mask_hidden_layers": 64,
    "fuse_conv_channels": 64,
    "representation_size": 64,  # 32
    # "clinical_input_channels": 64,
    # "clinical_conv_channels": 64,
    # "clinical_expand_conv_channels": 64,
    "backbone_out_channels": 64,
}

mobilenet_args = {
    "backbone": "mobilenet_v3",
    "using_fpn": False,
}

resnet_args = {
    "backbone": "resnet18",
    "using_fpn": False,
}

densenet_args = {
    "backbone": "densenet161",
    "using_fpn": False,
}

efficientnet_b0_args = {
    "backbone": "efficientnet_b0",
    "using_fpn": False,
}

efficientnet_b5_args = {
    "backbone": "efficientnet_b5",
    "using_fpn": False,
}

vgg16_args = {
    "backbone": "vgg16",
    "using_fpn": False,
}

# "sources": [SourceStrs.XRAYS, SourceStrs.CLINICAL,],
# "tasks": [
#     # TaskStrs.LESION_DETECTION,
#     TaskStrs.FIXATION_GENERATION,
#     TaskStrs.CHEXPERT_CLASSIFICATION,
#     TaskStrs.NEGBIO_CLASSIFICATION,
# ],
# "performance_standard_task": TaskStrs.CHEXPERT_CLASSIFICATION,
# "performance_standard_metric": "auc",
# "performance_standard_task": TaskStrs.LESION_DETECTION,
# "performance_standard_metric": "ap",

# %%
all_model_setups = [
    ModelSetup(
        name="lesion_dsetection_with_fixation_vgg16",
        **lesion_detection_best_args,
        **vgg16_args,
        **small_model_args,
        **common_args,
        **with_fix_args,
    ),
    ModelSetup(
        name="lesion_dsetection_baseline_vgg16",
        **lesion_detection_best_args,
        **vgg16_args,
        **small_model_args,
        **common_args,
        **without_fix_args,
    ),
]

# pick the best one.

# %%
# train possible trainable arguement for the

# %%
num_epochs = 50
train_infos: list[TrainingInfo] = []

# %%
# we have to mention that in order to provide objective evaluation, we compromise the dataset size, which also nagatively afftect the performance and generlaization.
for setup in all_model_setups:
    
    device = clean_memory_get_device()
    reproducibility()

    assert (
        len(setup.sources) > 0 and len(setup.tasks) > 0
    ), "Need at least one source and task."

    print_f.print_title("Preparing for the training.")

    train_info = TrainingInfo(setup)

    model = create_model_from_setup(setup=setup)
    model = model.to(device)

    train_info.all_tasks = list(model.task_performers.keys())
    print(f" Model Size [{get_model_size_in_MB(model):.3f}] MB")

    ################ Datasets ################
    dataset_params_dict = {
        "MIMIC_EYE_PATH": MIMIC_EYE_PATH,
        "labels_cols": setup.lesion_label_cols,
        "with_xrays_input": SourceStrs.XRAYS in setup.sources,
        "with_clincal_input": SourceStrs.CLINICAL in setup.sources,
        "with_fixations_input": SourceStrs.FIXATIONS in setup.sources,
        "fiaxtions_mode_input": setup.fiaxtions_mode_input,
        "with_bboxes_label": TaskStrs.LESION_DETECTION in setup.tasks,
        "with_fixations_label": TaskStrs.FIXATION_GENERATION in setup.tasks,
        "fiaxtions_mode_label": setup.fiaxtions_mode_label,
        "with_chexpert_label": TaskStrs.CHEXPERT_CLASSIFICATION in setup.tasks,
        "with_negbio_label": TaskStrs.NEGBIO_CLASSIFICATION in setup.tasks,
        "clinical_numerical_cols": setup.clinical_num,
        "clinical_categorical_cols": setup.clinical_cat,
        "image_size": setup.image_size,
        "image_mean": setup.image_mean,
        "image_std": setup.image_std,
    }

    detect_eval_dataset, train_dataset, val_dataset, test_dataset = get_datasets(
        dataset_params_dict=dataset_params_dict,
    )

    train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
        train_dataset, val_dataset, test_dataset, batch_size=setup.batch_size,
    )

    train_coco = None
    val_coco = None
    test_coco = None
    eval_params_dict = None

    if TaskStrs.LESION_DETECTION in setup.tasks:
        train_coco, val_coco, test_coco, eval_params_dict = get_coco_eval_params(
            source_name=SourceStrs.XRAYS,
            task_name=TaskStrs.LESION_DETECTION,
            train_dataloader=train_dataloader,
            val_dataloader=val_dataloader,
            test_dataloader=test_dataloader,
            detect_eval_dataset=detect_eval_dataset,
            iou_thrs=setup.iou_thrs,
            use_iobb=setup.use_iobb,
        )

    train_info.timer.start_training()


    dynamic_loss_weight = None
    if setup.use_dynamic_weight:
        dynamic_loss_weight = get_dynamic_loss(
            loss_keys=model.get_all_losses_keys(), device=device
        )
        
    params = model.get_all_params(dynamic_loss_weight=dynamic_loss_weight)

    iou_types = get_iou_types(model, setup)
    optimizer = get_optimiser(params, setup)
    lr_scheduler = get_lr_scheduler(optimizer, setup)

    print_f.print_title(
        f"Start training. Preparing Took [{train_info.timer.has_took_sec_from_init()}] sec"
    )

    train_info.timer.start_training()

    val_loss = None

    # Start the training from here.
    for e in range(1, num_epochs + 1):

        print_f.print_title(f"Training model: [{setup.name}]")

        print(train_info)
        if dynamic_loss_weight:
            for k,v  in dynamic_loss_weight.params.items():
                print(f"[{k}]: {v.item():.4f}")

        train_info.epoch = e

        train_info.timer.start_epoch()

        if (
            any(
                [
                    isinstance(p, ObjectDetectionPerformer)
                    for p in model.task_performers.values()
                ]
            )
            and train_info.epoch > setup.gt_in_train_till
        ):
            model.task_performers[
                TaskStrs.LESION_DETECTION
            ].roi_heads.use_gt_in_train = False

        ###### Perform training and show the training result here ######
        model.train()

        train_info.last_train_evaluator, train_loger = train_one_epoch(
            setup=setup,
            model=model,
            optimizer=optimizer,
            data_loader=train_dataloader,
            # data_loader=test_dataloader,
            device=device,
            epoch=train_info.epoch,
            print_freq=10,
            iou_types=iou_types,
            coco=train_coco,
            score_thres=None,
            evaluate_on_run=True,
            params_dict=eval_params_dict,
            dynamic_loss_weight=dynamic_loss_weight,
        )

        # train_info.train_evaluators.append(train_evaluator)
        train_info.train_losses.append(get_data_from_metric_logger(train_loger))
        ################################################################

        ####### Put the model into evaluation mode, start evaluating the current model #######
        model.eval()

        train_info.last_val_evaluator, val_logger = evaluate(
            setup=setup,
            model=model,
            data_loader=val_dataloader,
            device=device,
            params_dict=eval_params_dict,
            coco=val_coco,
            iou_types=iou_types,
            score_thres=None,
        )

        # train_info.val_evaluators.append(val_evaluator)
        train_info.val_losses.append(get_data_from_metric_logger(val_logger))

        train_info.performance["train"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_train_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        train_info.performance["val"].append(
            get_performance(
                train_info.all_tasks,
                train_info.last_val_evaluator,
                iouThr=0.5,
                areaRng="all",
                maxDets=10,
            )
        )

        if setup.measure_test:
            train_info.test_evaluator, test_logger = evaluate(
                setup=setup,
                model=model,
                data_loader=test_dataloader,
                device=device,
                params_dict=eval_params_dict,
                coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
            )
            train_info.test_losses.append(get_data_from_metric_logger(test_logger))

            train_info.performance["test"].append(
                get_performance(
                    train_info.all_tasks,
                    train_info.test_evaluator,
                    iouThr=0.5,
                    areaRng="all",
                    maxDets=10,
                )
            )

        # update the learning rate

        # use Average Precision (Performance value) instead of loss in lr_scheduler.
        # val_loss = train_info.val_losses[-1]["loss"]
        val_performance_value = train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric]

        epoch_took, sec_already_took, speed = train_info.timer.end_epoch(
            train_info.epoch
        )

        if train_info.epoch > setup.warmup_epochs:
            if not lr_scheduler is None:
                if isinstance(lr_scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    if (
                        setup.reduceLROnPlateau_full_stop
                        and lr_scheduler.num_bad_epochs
                        >= setup.reduceLROnPlateau_patience
                    ):
                        print_f.print_title(
                            f"| EarlyStop | Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec |"
                        )
                        break
                    lr_scheduler.step(val_performance_value)
                else:
                    lr_scheduler.step()

        # Clean everything before we show the evaluating result in this stage, so we can inspect the training progress.
        clear_output()

        # if model_setup.record_training_performance:
        # plot all matrics
        plot_performance(
            performance=train_info.performance,
            all_tasks=train_info.all_tasks,
            fig_title="Performance",
        )

        plot_losses(
            train_info.train_losses,
            train_info.val_losses,
            test_logers=train_info.test_losses,
        )

        print_str = f"| Epoch [{train_info.epoch}] Done | It has took [{sec_already_took/60:.2f}] min, Avg time: [{speed:.2f}] sec/epoch | Estimate time for [{num_epochs}] epochs: [{speed*num_epochs/60:.2f}] min | Epoch took [{epoch_took.seconds}] sec | "

        if lr_scheduler and hasattr(lr_scheduler, "num_bad_epochs"):
            print_str += f"Patience [{lr_scheduler.num_bad_epochs}] |"

        print_f.print_title(print_str)

        train_info

        #######################################################################################
        if setup.save_early_stop_model:
            val_performance_value, train_info = check_best(
                setup=setup,
                val_performance_value=train_info.performance["val"][-1][
                    setup.performance_standard_task
                ][setup.performance_standard_metric],
                device=device,
                eval_params_dict=eval_params_dict,
                train_info=train_info,
                model=model,
                optim=optimizer,
                test_dataloader=test_dataloader,
                test_coco=test_coco,
                iou_types=iou_types,
                score_thres=None,
                dynamic_weight=dynamic_loss_weight,
            )
 
    train_info = end_train(
        setup=setup,
        train_info=train_info,
        model=model,
        optim=optimizer,
        eval_params_dict=eval_params_dict,
        last_val_performance=train_info.performance["val"][-1][
            setup.performance_standard_task
        ][setup.performance_standard_metric],
        test_dataloader=test_dataloader,
        device=device,
        test_coco=test_coco,
        iou_types=iou_types,
        score_thres=None,
        dynamic_weight=dynamic_loss_weight,
    )

    train_infos.append(train_info)

# TODO: allow for any kind of pipeline.
## bb is not resized
# 0.02?
# 1645m 53.7s
# Out:
# ====================| Epoch [22] Done | It has took [196.88] min, Avg time: [536.95] sec/epoch | Estimate time for [50] epochs: [447.46] min | Epoch took [509] sec | Patience [10] |====================
# ====================Training model: [lesion_dsetection_baseline_vgg16]====================
# ========================================For Training [lesion_dsetection_baseline_vgg16]========================================
# ModelSetup(name='lesion_dsetection_baseline_vgg16', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='vgg16', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ===============================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2113_test_lesion-detection_ap_0_2068_epoch12_03-21-2023 00-45-24_lesion_dsetection_baseline_vgg16]
# The final model has been saved to: [val_lesion-detection_ap_0_2113_test_lesion-detection_ap_0_2068_epoch12_03-21-2023 00-45-24_lesion_dsetection_baseline_vgg16]
#
# ===============================================================================================================================
# [lesion-detection_performer-object_detection_loss_box_reg]: 0.4138
# [lesion-detection_performer-object_detection_loss_classifier]: 0.4224
# [lesion-detection_performer-object_detection_loss_mask]: 1.0000
# [lesion-detection_performer-object_detection_loss_objectness]: 0.2698
# [lesion-detection_performer-object_detection_loss_rpn_box_reg]: 0.1975
# backbone weights fix status: False
# Epoch: [23]  [  0/266]  eta: 0:06:11  lr: 0.010000  loss: 0.0504 (0.0504)  lesion-detection_performer-object_detection_loss_classifier: 0.0268 (0.0268)  lesion-detection_performer-object_detection_loss_box_reg: 0.0158 (0.0158)  lesion-detection_performer-object_detection_loss_objectness: 0.0068 (0.0068)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0010 (0.0010)  time: 1.3974  data: 0.9283  max mem: 6452
# Epoch: [23]  [ 10/266]  eta: 0:05:01  lr: 0.010000  loss: 0.1014 (0.1225)  lesion-detection_performer-object_detection_loss_classifier: 0.0473 (0.0588)  lesion-detection_performer-object_detection_loss_box_reg: 0.0479 (0.0532)  lesion-detection_performer-object_detection_loss_objectness: 0.0070 (0.0087)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0018)  time: 1.1763  data: 0.9219  max mem: 6452
# Epoch: [23]  [ 20/266]  eta: 0:04:46  lr: 0.010000  loss: 0.1044 (0.1218)  lesion-detection_performer-object_detection_loss_classifier: 0.0518 (0.0579)  lesion-detection_performer-object_detection_loss_box_reg: 0.0479 (0.0532)  lesion-detection_performer-object_detection_loss_objectness: 0.0078 (0.0087)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0019)  time: 1.1519  data: 0.9162  max mem: 6452
# Epoch: [23]  [ 30/266]  eta: 0:04:32  lr: 0.010000  loss: 0.1074 (0.1224)  lesion-detection_performer-object_detection_loss_classifier: 0.0523 (0.0577)  lesion-detection_performer-object_detection_loss_box_reg: 0.0507 (0.0543)  lesion-detection_performer-object_detection_loss_objectness: 0.0078 (0.0084)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  time: 1.1453  data: 0.9094  max mem: 6452
# Epoch: [23]  [ 40/266]  eta: 0:04:21  lr: 0.010000  loss: 0.1103 (0.1253)  lesion-detection_performer-object_detection_loss_classifier: 0.0513 (0.0595)  lesion-detection_performer-object_detection_loss_box_reg: 0.0532 (0.0557)  lesion-detection_performer-object_detection_loss_objectness: 0.0073 (0.0081)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0020)  time: 1.1457  data: 0.9095  max mem: 6452
# Epoch: [23]  [ 50/266]  eta: 0:04:08  lr: 0.010000  loss: 0.1207 (0.1298)  lesion-detection_performer-object_detection_loss_classifier: 0.0579 (0.0613)  lesion-detection_performer-object_detection_loss_box_reg: 0.0535 (0.0580)  lesion-detection_performer-object_detection_loss_objectness: 0.0074 (0.0083)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0022)  time: 1.1442  data: 0.9069  max mem: 6452
# Epoch: [23]  [ 60/266]  eta: 0:03:55  lr: 0.010000  loss: 0.1318 (0.1328)  lesion-detection_performer-object_detection_loss_classifier: 0.0596 (0.0622)  lesion-detection_performer-object_detection_loss_box_reg: 0.0564 (0.0597)  lesion-detection_performer-object_detection_loss_objectness: 0.0079 (0.0086)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0024 (0.0023)  time: 1.1251  data: 0.8897  max mem: 6452
# Epoch: [23]  [ 70/266]  eta: 0:03:44  lr: 0.010000  loss: 0.1178 (0.1304)  lesion-detection_performer-object_detection_loss_classifier: 0.0529 (0.0610)  lesion-detection_performer-object_detection_loss_box_reg: 0.0539 (0.0588)  lesion-detection_performer-object_detection_loss_objectness: 0.0070 (0.0084)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 1.1253  data: 0.8892  max mem: 6452
# Epoch: [23]  [ 80/266]  eta: 0:03:32  lr: 0.010000  loss: 0.1058 (0.1303)  lesion-detection_performer-object_detection_loss_classifier: 0.0520 (0.0610)  lesion-detection_performer-object_detection_loss_box_reg: 0.0515 (0.0585)  lesion-detection_performer-object_detection_loss_objectness: 0.0078 (0.0087)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0018 (0.0022)  time: 1.1266  data: 0.8931  max mem: 6452
# Epoch: [23]  [ 90/266]  eta: 0:03:20  lr: 0.010000  loss: 0.1310 (0.1329)  lesion-detection_performer-object_detection_loss_classifier: 0.0610 (0.0620)  lesion-detection_performer-object_detection_loss_box_reg: 0.0544 (0.0595)  lesion-detection_performer-object_detection_loss_objectness: 0.0108 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.1215  data: 0.8859  max mem: 6452
# Epoch: [23]  [100/266]  eta: 0:03:09  lr: 0.010000  loss: 0.1450 (0.1341)  lesion-detection_performer-object_detection_loss_classifier: 0.0649 (0.0626)  lesion-detection_performer-object_detection_loss_box_reg: 0.0670 (0.0601)  lesion-detection_performer-object_detection_loss_objectness: 0.0091 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0028 (0.0023)  time: 1.1413  data: 0.9023  max mem: 6452
# Epoch: [23]  [110/266]  eta: 0:02:57  lr: 0.010000  loss: 0.1356 (0.1336)  lesion-detection_performer-object_detection_loss_classifier: 0.0596 (0.0622)  lesion-detection_performer-object_detection_loss_box_reg: 0.0594 (0.0598)  lesion-detection_performer-object_detection_loss_objectness: 0.0082 (0.0093)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.1352  data: 0.8972  max mem: 6452
# Epoch: [23]  [120/266]  eta: 0:02:46  lr: 0.010000  loss: 0.1319 (0.1337)  lesion-detection_performer-object_detection_loss_classifier: 0.0529 (0.0621)  lesion-detection_performer-object_detection_loss_box_reg: 0.0570 (0.0600)  lesion-detection_performer-object_detection_loss_objectness: 0.0080 (0.0093)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.1248  data: 0.8866  max mem: 6452
# Epoch: [23]  [130/266]  eta: 0:02:34  lr: 0.010000  loss: 0.1509 (0.1350)  lesion-detection_performer-object_detection_loss_classifier: 0.0667 (0.0629)  lesion-detection_performer-object_detection_loss_box_reg: 0.0600 (0.0606)  lesion-detection_performer-object_detection_loss_objectness: 0.0077 (0.0093)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.1413  data: 0.9048  max mem: 6452
# Epoch: [23]  [140/266]  eta: 0:02:23  lr: 0.010000  loss: 0.1509 (0.1361)  lesion-detection_performer-object_detection_loss_classifier: 0.0667 (0.0634)  lesion-detection_performer-object_detection_loss_box_reg: 0.0678 (0.0612)  lesion-detection_performer-object_detection_loss_objectness: 0.0075 (0.0092)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.1567  data: 0.9172  max mem: 6452
# Epoch: [23]  [150/266]  eta: 0:02:12  lr: 0.010000  loss: 0.1399 (0.1360)  lesion-detection_performer-object_detection_loss_classifier: 0.0618 (0.0631)  lesion-detection_performer-object_detection_loss_box_reg: 0.0678 (0.0615)  lesion-detection_performer-object_detection_loss_objectness: 0.0071 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.1464  data: 0.9085  max mem: 6452
# Epoch: [23]  [160/266]  eta: 0:02:00  lr: 0.010000  loss: 0.1374 (0.1373)  lesion-detection_performer-object_detection_loss_classifier: 0.0610 (0.0636)  lesion-detection_performer-object_detection_loss_box_reg: 0.0755 (0.0623)  lesion-detection_performer-object_detection_loss_objectness: 0.0071 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.1459  data: 0.9092  max mem: 6452
# Epoch: [23]  [170/266]  eta: 0:01:49  lr: 0.010000  loss: 0.1364 (0.1357)  lesion-detection_performer-object_detection_loss_classifier: 0.0618 (0.0629)  lesion-detection_performer-object_detection_loss_box_reg: 0.0524 (0.0614)  lesion-detection_performer-object_detection_loss_objectness: 0.0096 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.1546  data: 0.9171  max mem: 6452
# Epoch: [23]  [180/266]  eta: 0:01:38  lr: 0.010000  loss: 0.1158 (0.1346)  lesion-detection_performer-object_detection_loss_classifier: 0.0501 (0.0623)  lesion-detection_performer-object_detection_loss_box_reg: 0.0519 (0.0611)  lesion-detection_performer-object_detection_loss_objectness: 0.0081 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.1502  data: 0.9145  max mem: 6452
# Epoch: [23]  [190/266]  eta: 0:01:26  lr: 0.010000  loss: 0.1158 (0.1349)  lesion-detection_performer-object_detection_loss_classifier: 0.0513 (0.0625)  lesion-detection_performer-object_detection_loss_box_reg: 0.0577 (0.0611)  lesion-detection_performer-object_detection_loss_objectness: 0.0073 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0023)  time: 1.1583  data: 0.9200  max mem: 6452
# Epoch: [23]  [200/266]  eta: 0:01:15  lr: 0.010000  loss: 0.1129 (0.1342)  lesion-detection_performer-object_detection_loss_classifier: 0.0502 (0.0622)  lesion-detection_performer-object_detection_loss_box_reg: 0.0489 (0.0606)  lesion-detection_performer-object_detection_loss_objectness: 0.0085 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0017 (0.0023)  time: 1.1580  data: 0.9205  max mem: 6452
# Epoch: [23]  [210/266]  eta: 0:01:04  lr: 0.010000  loss: 0.1381 (0.1355)  lesion-detection_performer-object_detection_loss_classifier: 0.0580 (0.0626)  lesion-detection_performer-object_detection_loss_box_reg: 0.0623 (0.0613)  lesion-detection_performer-object_detection_loss_objectness: 0.0091 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0023)  time: 1.1429  data: 0.9062  max mem: 6452
# Epoch: [23]  [220/266]  eta: 0:00:52  lr: 0.010000  loss: 0.1486 (0.1364)  lesion-detection_performer-object_detection_loss_classifier: 0.0666 (0.0629)  lesion-detection_performer-object_detection_loss_box_reg: 0.0693 (0.0618)  lesion-detection_performer-object_detection_loss_objectness: 0.0094 (0.0093)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.1442  data: 0.9072  max mem: 6452
# Epoch: [23]  [230/266]  eta: 0:00:41  lr: 0.010000  loss: 0.1321 (0.1358)  lesion-detection_performer-object_detection_loss_classifier: 0.0607 (0.0627)  lesion-detection_performer-object_detection_loss_box_reg: 0.0597 (0.0615)  lesion-detection_performer-object_detection_loss_objectness: 0.0072 (0.0092)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0024)  time: 1.1331  data: 0.8974  max mem: 6452
# Epoch: [23]  [240/266]  eta: 0:00:29  lr: 0.010000  loss: 0.1249 (0.1350)  lesion-detection_performer-object_detection_loss_classifier: 0.0596 (0.0623)  lesion-detection_performer-object_detection_loss_box_reg: 0.0544 (0.0612)  lesion-detection_performer-object_detection_loss_objectness: 0.0070 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0019 (0.0023)  time: 1.1430  data: 0.9098  max mem: 6452
# Epoch: [23]  [250/266]  eta: 0:00:18  lr: 0.010000  loss: 0.1218 (0.1348)  lesion-detection_performer-object_detection_loss_classifier: 0.0561 (0.0624)  lesion-detection_performer-object_detection_loss_box_reg: 0.0533 (0.0611)  lesion-detection_performer-object_detection_loss_objectness: 0.0074 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0015 (0.0023)  time: 1.1580  data: 0.9247  max mem: 6452
# Epoch: [23]  [260/266]  eta: 0:00:06  lr: 0.010000  loss: 0.1218 (0.1344)  lesion-detection_performer-object_detection_loss_classifier: 0.0536 (0.0621)  lesion-detection_performer-object_detection_loss_box_reg: 0.0551 (0.0609)  lesion-detection_performer-object_detection_loss_objectness: 0.0083 (0.0091)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0023)  time: 1.1484  data: 0.9122  max mem: 6452
# Epoch: [23]  [265/266]  eta: 0:00:01  lr: 0.010000  loss: 0.1271 (0.1344)  lesion-detection_performer-object_detection_loss_classifier: 0.0594 (0.0621)  lesion-detection_performer-object_detection_loss_box_reg: 0.0564 (0.0609)  lesion-detection_performer-object_detection_loss_objectness: 0.0092 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0023)  time: 1.1055  data: 0.8768  max mem: 6452
# Epoch: [23] Total time: 0:05:03 (1.1412 s / it)
# Averaged stats: lr: 0.010000  loss: 0.1271 (0.1344)  lesion-detection_performer-object_detection_loss_classifier: 0.0594 (0.0621)  lesion-detection_performer-object_detection_loss_box_reg: 0.0564 (0.0609)  lesion-detection_performer-object_detection_loss_objectness: 0.0092 (0.0090)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0021 (0.0023)
# Accumulating evaluation results...
# DONE (t=0.18s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.226
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.226
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.231
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.493
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.493
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.494
# Evaluation:  [ 0/57]  eta: 0:01:42  loss: 0.2951 (0.2951)  lesion-detection_performer-object_detection_loss_classifier: 0.1401 (0.1401)  lesion-detection_performer-object_detection_loss_box_reg: 0.0906 (0.0906)  lesion-detection_performer-object_detection_loss_objectness: 0.0566 (0.0566)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0077 (0.0077)  model_time: 1679328896.0000 (1679328931.6552)  evaluator_time: 0.0000 (0.0000)  time: 1.8062  data: 1.5989  max mem: 6452
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2036 (0.2098)  lesion-detection_performer-object_detection_loss_classifier: 0.1009 (0.1057)  lesion-detection_performer-object_detection_loss_box_reg: 0.0668 (0.0682)  lesion-detection_performer-object_detection_loss_objectness: 0.0243 (0.0315)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0044)  model_time: 1679329024.0000 (1679328982.3875)  evaluator_time: 0.0000 (0.0000)  time: 1.8188  data: 1.6119  max mem: 6452
# Evaluation: Total time: 0:01:43 (1.8097 s / it)
# Averaged stats: loss: 0.2036 (0.2098)  lesion-detection_performer-object_detection_loss_classifier: 0.1009 (0.1057)  lesion-detection_performer-object_detection_loss_box_reg: 0.0668 (0.0682)  lesion-detection_performer-object_detection_loss_objectness: 0.0243 (0.0315)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0036 (0.0044)  model_time: 1679329024.0000 (1679328982.3875)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.189
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.244
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.484
# Evaluation:  [ 0/57]  eta: 0:01:47  loss: 0.1287 (0.1287)  lesion-detection_performer-object_detection_loss_classifier: 0.0538 (0.0538)  lesion-detection_performer-object_detection_loss_box_reg: 0.0684 (0.0684)  lesion-detection_performer-object_detection_loss_objectness: 0.0045 (0.0045)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0020 (0.0020)  model_time: 1679329024.0000 (1679329034.9805)  evaluator_time: 0.0000 (0.0000)  time: 1.8922  data: 1.6878  max mem: 6452
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.1897 (0.1939)  lesion-detection_performer-object_detection_loss_classifier: 0.0987 (0.0979)  lesion-detection_performer-object_detection_loss_box_reg: 0.0572 (0.0645)  lesion-detection_performer-object_detection_loss_objectness: 0.0303 (0.0276)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0039)  model_time: 1679329152.0000 (1679329085.0778)  evaluator_time: 0.0000 (0.0000)  time: 1.8703  data: 1.6496  max mem: 6452
# Evaluation: Total time: 0:01:42 (1.8068 s / it)
# Averaged stats: loss: 0.1897 (0.1939)  lesion-detection_performer-object_detection_loss_classifier: 0.0987 (0.0979)  lesion-detection_performer-object_detection_loss_box_reg: 0.0572 (0.0645)  lesion-detection_performer-object_detection_loss_objectness: 0.0303 (0.0276)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0035 (0.0039)  model_time: 1679329152.0000 (1679329085.0778)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.189
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.244
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.498
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.498
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.498
# ====================| EarlyStop | Epoch [23] Done | It has took [205.42] min, Avg time: [535.87] sec/epoch | Estimate time for [50] epochs: [446.56] min | Epoch took [510] sec |====================
# ====================| Training Done, start testing! | [23] Epochs Training time: [12325] seconds, Avg time / Epoch: [535.8695652173913] seconds====================
# ====================Best Performance model has been saved to: [val_lesion-detection_ap_0_2113_test_lesion-detection_ap_0_2068_epoch12_03-21-2023 00-45-24_lesion_dsetection_baseline_vgg16]====================
# Evaluation:  [ 0/57]  eta: 0:01:53  loss: 0.2682 (0.2682)  lesion-detection_performer-object_detection_loss_classifier: 0.1280 (0.1280)  lesion-detection_performer-object_detection_loss_box_reg: 0.0949 (0.0949)  lesion-detection_performer-object_detection_loss_objectness: 0.0393 (0.0393)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0060 (0.0060)  model_time: 1679329152.0000 (1679329138.0216)  evaluator_time: 0.0000 (0.0000)  time: 1.9991  data: 1.6314  max mem: 6452
# Evaluation:  [56/57]  eta: 0:00:01  loss: 0.2338 (0.1936)  lesion-detection_performer-object_detection_loss_classifier: 0.1007 (0.0976)  lesion-detection_performer-object_detection_loss_box_reg: 0.0657 (0.0644)  lesion-detection_performer-object_detection_loss_objectness: 0.0218 (0.0276)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0039)  model_time: 1679329280.0000 (1679329188.7998)  evaluator_time: 0.0000 (0.0000)  time: 1.8073  data: 1.5909  max mem: 6452
# Evaluation: Total time: 0:01:42 (1.8021 s / it)
# Averaged stats: loss: 0.2338 (0.1936)  lesion-detection_performer-object_detection_loss_classifier: 0.1007 (0.0976)  lesion-detection_performer-object_detection_loss_box_reg: 0.0657 (0.0644)  lesion-detection_performer-object_detection_loss_objectness: 0.0218 (0.0276)  lesion-detection_performer-object_detection_loss_rpn_box_reg: 0.0038 (0.0039)  model_time: 1679329280.0000 (1679329188.7998)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50      | area=   all | maxDets= 10 ] = 0.190
#  Average Precision  (AP) @[ IoBB=0.75      | area=   all | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Precision  (AP) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.190
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets=  1 ] = 0.247
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.499
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=   all | maxDets= 10 ] = 0.499
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= small | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area=medium | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoBB=0.50:0.50 | area= large | maxDets= 10 ] = 0.499
# ====================The final model has been saved to: [val_lesion-detection_ap_0_1892_test_lesion-detection_ap_0_1899_epoch23_03-21-2023 02-20-39_lesion_dsetection_baseline_vgg16]====================

# %%
# import matplotlib.pyplot as plt
# # target_heatmap = model.evaluators['fixation-generation'].targets[0]['heatmaps'] 
# d_heatmap = train_dataset[0][1]['fixation-generation']['heatmaps']
# plt.imshow(d_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()
# interpolated_heatmap = torch.nn.functional.interpolate(
#             d_heatmap[:, None].float(), size=(512, 512),
#         )[:, 0]
# plt.imshow((interpolated_heatmap/interpolated_heatmap.max()).permute(1,2,0).to("cpu").numpy())
# plt.show()
# transformed = model.task_performers[
#             TaskStrs.FIXATION_GENERATION
#         ].transform([train_dataset[0][0]['xrays']['images']], [train_dataset[0][1]])
# transform_heatmap = transformed[1][0]['fixation-generation']['heatmaps']
# plt.imshow(transform_heatmap.permute(1,2,0).to("cpu").numpy())
# plt.show()

# %%
for train_info in train_infos :
    print(train_info)
    plot_performance(
        performance=train_info.performance,
        all_tasks=train_info.all_tasks,
        fig_title="Performance",
    )
    plot_losses(
        train_info.train_losses,
        train_info.val_losses,
        test_logers=train_info.test_losses,
    )
# Out:
# ========================================For Training [lesion_dsetection_with_fixation_vgg16]========================================
# ModelSetup(name='lesion_dsetection_with_fixation_vgg16', sources=['xrays', 'fixations'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='vgg16', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ====================================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2301_test_lesion-detection_ap_0_2186_epoch22_03-20-2023 19-26-02_lesion_dsetection_with_fixation_vgg16]
# The final model has been saved to: [val_lesion-detection_ap_0_1805_test_lesion-detection_ap_0_1941_epoch33_03-20-2023 22-53-28_lesion_dsetection_with_fixation_vgg16]
#
# ====================================================================================================================================
# ========================================For Training [lesion_dsetection_baseline_vgg16]========================================
# ModelSetup(name='lesion_dsetection_baseline_vgg16', sources=['xrays'], tasks=['lesion-detection'], fusor='element-wise sum', decoder_channels=[128, 64, 32, 16, 8], lesion_label_cols=['Pulmonary edema', 'Enlarged cardiac silhouette', 'Consolidation', 'Atelectasis', 'Pleural abnormality'], save_early_stop_model=True, record_training_performance=False, backbone='vgg16', optimiser='sgd', lr=0.01, weight_decay=1e-05, sgb_momentum=0.9, image_backbone_pretrained=True, heatmap_backbone_pretrained=False, image_size=512, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225], backbone_out_channels=64, batch_size=8, warmup_epochs=0, model_warmup_epochs=0, loss_warmup_epochs=0, lr_scheduler='ReduceLROnPlateau', reduceLROnPlateau_factor=0.5, reduceLROnPlateau_patience=10, reduceLROnPlateau_full_stop=True, multiStepLR_milestones=[20, 40, 60, 80, 100], multiStepLR_gamma=0.5, representation_size=64, mask_hidden_layers=64, using_fpn=False, use_mask=False, fuse_conv_channels=64, box_head_dropout_rate=0, fuse_depth=4, fusion_strategy='concat', fusion_residule=False, gt_in_train_till=0, measure_test=True, eval_freq=10, use_iobb=True, iou_thrs=array([0.5]), fiaxtions_mode_input='reporting', fiaxtions_mode_label='reporting', clinical_num=['age', 'temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity'], clinical_cat=['gender'], categorical_col_maps={'gender': 2}, clinical_cat_emb_dim=32, clinical_conv_channels=32, clinical_upsample='deconv', chexpert_label_cols=['Atelectasis_chexpert', 'Cardiomegaly_chexpert', 'Consolidation_chexpert', 'Edema_chexpert', 'Enlarged Cardiomediastinum_chexpert', 'Fracture_chexpert', 'Lung Lesion_chexpert', 'Lung Opacity_chexpert', 'No Finding_chexpert', 'Pleural Effusion_chexpert', 'Pleural Other_chexpert', 'Pneumonia_chexpert', 'Pneumothorax_chexpert', 'Support Devices_chexpert'], negbio_label_cols=['Atelectasis_negbio', 'Cardiomegaly_negbio', 'Consolidation_negbio', 'Edema_negbio', 'Enlarged Cardiomediastinum_negbio', 'Fracture_negbio', 'Lung Lesion_negbio', 'Lung Opacity_negbio', 'No Finding_negbio', 'Pleural Effusion_negbio', 'Pleural Other_negbio', 'Pneumonia_negbio', 'Pneumothorax_negbio', 'Support Devices_negbio'], performance_standard_task='lesion-detection', performance_standard_metric='ap', random_flip=True, use_dynamic_weight=True)
# ===============================================================================================================================
#
# Best performance model has been saved to: [val_lesion-detection_ap_0_2113_test_lesion-detection_ap_0_2068_epoch12_03-21-2023 00-45-24_lesion_dsetection_baseline_vgg16]
# The final model has been saved to: [val_lesion-detection_ap_0_1892_test_lesion-detection_ap_0_1899_epoch23_03-21-2023 02-20-39_lesion_dsetection_baseline_vgg16]
#
# ===============================================================================================================================

# %%
# create the file to inspect the heatmap generated by the model.
